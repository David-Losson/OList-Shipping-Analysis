# %%
import pandas as pd
import numpy as np
import os
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
path = r'C:\Users\dmlos\Achievement VI- Olist Business Analysis'

# %%
#importing customer data from the project folder

df_customers = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_customers_dataset.csv', index_col = False)

# %%
#importing order items data from the project folder

df_customers = pd.read_csv(os.path.join(path,'Olist-Original Data (Kaggle)', 'olist_customers_dataset.csv'), index_col = False)

# %%
#importing geolocation data from the project folder

df_geolocation = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_geolocation_dataset.csv', index_col = False)

# %%
#importing order items data from the project folder

df_order_items = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_order_items_dataset.csv', index_col = False)

# %%
#importing order payments data from the project folder

df_order_payments = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_order_payments_dataset.csv', index_col = False)

# %%
#importing order reviews data from the project folder

df_order_reviews = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_order_reviews_dataset.csv', index_col = False)

# %%
#importing orders data from the project folder

df_orders = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_orders_dataset.csv', index_col = False)

# %%
#importing products data from the project folder

df_products = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_products_dataset.csv', index_col = False)

# %%
#importing sellers data from the project folder

df_sellers = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_sellers_dataset.csv', index_col = False)

# %%
#importing product category name translated from Portuguese to English

df_product_translation = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\product_category_name_translation.csv', index_col = False)

# %% [markdown]
# # Merge Files

# %%
df_reviews_orders = df_order_reviews.merge(df_orders, on = 'order_id')

# %%
df_reviews_orders_payments = df_order_payments.merge(df_reviews_orders, on = 'order_id')

# %%
df_review_orders_payments_items = df_order_items.merge(df_reviews_orders_payments, on = 'order_id')

# %%
df_review_orders_payments_items_products = df_products.merge(df_review_orders_payments_items, on = 'product_id')

# %%
df_review_orders_payments_items_products_sellers = df_sellers.merge(df_review_orders_payments_items_products, on = 'seller_id')

# %%
df_review_orders_payments_items_products_sellers_customers = df_customers.merge(df_review_orders_payments_items_products_sellers, on = 'customer_id')

# %%
df_review_orders_payments_items_products_sellers_customers
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 117324  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 117325  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 117326  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 117327  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 117328  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %%
df_review_orders_payments_items_products_sellers_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    117329 non-null  object
#  1   customer_unique_id             117329 non-null  object
#  2   customer_zip_code_prefix       117329 non-null  int64
#  3   customer_city                  117329 non-null  object
#  4   customer_state                 117329 non-null  object
#  5   seller_id                      117329 non-null  object
#  6   seller_zip_code_prefix         117329 non-null  int64
#  7   seller_city                    117329 non-null  object
#  8   seller_state                   117329 non-null  object
#  9   product_id                     117329 non-null  object
#  10  product_category_name          115634 non-null  object
#  11  product_name_lenght            115634 non-null  float64
# ...

# %%
#Drop Unnecessary Columns
df_review_orders_payments_items_products_sellers_customers_1 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['product_name_lenght'])
df_review_orders_payments_items_products_sellers_customers_2 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['product_description_lenght'])
df_review_orders_payments_items_products_sellers_customers_3 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['product_photos_qty'])
df_review_orders_payments_items_products_sellers_customers_4 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['product_length_cm'])
df_review_orders_payments_items_products_sellers_customers_5 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['product_height_cm'])
df_review_orders_payments_items_products_sellers_customers_6 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['product_width_cm'])
df_review_orders_payments_items_products_sellers_customers_7 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['payment_sequential'])
df_review_orders_payments_items_products_sellers_customers_8 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['payment_installments'])
df_review_orders_payments_items_products_sellers_customers_9 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['payment_value'])
df_review_orders_payments_items_products_sellers_customers_10 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['review_id'])
df_review_orders_payments_items_products_sellers_customers_11 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['review_comment_title'])
df_review_orders_payments_items_products_sellers_customers_12 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['review_comment_message'])
df_review_orders_payments_items_products_sellers_customers_13 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['review_creation_date'])
df_review_orders_payments_items_products_sellers_customers_14 = df_review_orders_payments_items_products_sellers_customers.drop(columns = ['review_answer_timestamp'])

# %%
df_review_orders_payments_items_products_sellers_customers_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    117329 non-null  object
#  1   customer_unique_id             117329 non-null  object
#  2   customer_zip_code_prefix       117329 non-null  int64
#  3   customer_city                  117329 non-null  object
#  4   customer_state                 117329 non-null  object
#  5   seller_id                      117329 non-null  object
#  6   seller_zip_code_prefix         117329 non-null  int64
#  7   seller_city                    117329 non-null  object
#  8   seller_state                   117329 non-null  object
#  9   product_id                     117329 non-null  object
#  10  product_category_name          115634 non-null  object
#  11  product_name_lenght            115634 non-null  float64
# ...

# %%
#Convert the delivered, order purchase, order approved, estimated delivery, and order delivered to carrier dates to datetime format
df_review_orders_payments_items_products_sellers_customers_14['order_purchase_timestamp'] = df_review_orders_payments_items_products_sellers_customers_14['order_purchase_timestamp'].astype('datetime64[ns]')
df_review_orders_payments_items_products_sellers_customers_14['order_delivered_customer_date'] = df_review_orders_payments_items_products_sellers_customers_14['order_delivered_customer_date'].astype('datetime64[ns]')
df_review_orders_payments_items_products_sellers_customers_14['order_estimated_delivery_date'] = df_review_orders_payments_items_products_sellers_customers_14['order_estimated_delivery_date'].astype('datetime64[ns]')
df_review_orders_payments_items_products_sellers_customers_14['order_delivered_carrier_date'] = df_review_orders_payments_items_products_sellers_customers_14['order_delivered_carrier_date'].astype('datetime64[ns]')
df_review_orders_payments_items_products_sellers_customers_14['order_approved_at'] = df_review_orders_payments_items_products_sellers_customers_14['order_approved_at'].astype('datetime64[ns]')

# %%
df_review_orders_payments_items_products_sellers_customers_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    117329 non-null  object
#  1   customer_unique_id             117329 non-null  object
#  2   customer_zip_code_prefix       117329 non-null  int64
#  3   customer_city                  117329 non-null  object
#  4   customer_state                 117329 non-null  object
#  5   seller_id                      117329 non-null  object
#  6   seller_zip_code_prefix         117329 non-null  int64
#  7   seller_city                    117329 non-null  object
#  8   seller_state                   117329 non-null  object
#  9   product_id                     117329 non-null  object
#  10  product_category_name          115634 non-null  object
#  11  product_name_lenght            115634 non-null  float64
# ...

# %%
#Calculate the time difference between actual delivery date and order purchase date
df_review_orders_payments_items_products_sellers_customers_14 ['Delivery-Purchase_Time_Difference'] = df_review_orders_payments_items_products_sellers_customers_14['order_delivered_customer_date'] - df_review_orders_payments_items_products_sellers_customers_14['order_purchase_timestamp']

#Calculate the time difference between estimated delivery date and order purchase date
df_review_orders_payments_items_products_sellers_customers_14 ['Estimated-Purchase_Time_Difference'] = df_review_orders_payments_items_products_sellers_customers_14['order_estimated_delivery_date'] - df_review_orders_payments_items_products_sellers_customers_14['order_purchase_timestamp']

#Calculate the time difference between order approval date and order purchase date
df_review_orders_payments_items_products_sellers_customers_14 ['Approval-Purchase_Time_Difference'] = df_review_orders_payments_items_products_sellers_customers_14['order_approved_at'] - df_review_orders_payments_items_products_sellers_customers_14['order_purchase_timestamp']

#Calculate the time difference between delivery to the carrier and order purchase date
df_review_orders_payments_items_products_sellers_customers_14 ['Carrier_Delivered-Order_Time_Difference'] = df_review_orders_payments_items_products_sellers_customers_14['order_delivered_carrier_date'] - df_review_orders_payments_items_products_sellers_customers_14['order_purchase_timestamp']

# %%
df_review_orders_payments_items_products_sellers_customers_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 46 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   customer_id                                  117329 non-null  object
#  1   customer_unique_id                           117329 non-null  object
#  2   customer_zip_code_prefix                     117329 non-null  int64
#  3   customer_city                                117329 non-null  object
#  4   customer_state                               117329 non-null  object
#  5   seller_id                                    117329 non-null  object
#  6   seller_zip_code_prefix                       117329 non-null  int64
#  7   seller_city                                  117329 non-null  object
#  8   seller_state                                 117329 non-null  object
# ...

# %%
#Convert the calculated time differences into minute amounts in the integer or float format
df_review_orders_payments_items_products_sellers_customers_14 ['Delivery-Purchase_Time_Difference_Min'] = df_review_orders_payments_items_products_sellers_customers_14 ['Delivery-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_review_orders_payments_items_products_sellers_customers_14 ['Estimated-Purchase_Time_Difference_Min'] = df_review_orders_payments_items_products_sellers_customers_14 ['Estimated-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_review_orders_payments_items_products_sellers_customers_14 ['Approval-Purchase_Time_Difference_Min'] = df_review_orders_payments_items_products_sellers_customers_14 ['Approval-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_review_orders_payments_items_products_sellers_customers_14 ['Carrier_Delivered-Order_Time_Difference_Min'] = df_review_orders_payments_items_products_sellers_customers_14 ['Carrier_Delivered-Order_Time_Difference']/pd.Timedelta(minutes=1)

# %%
df_review_orders_payments_items_products_sellers_customers_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 46 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   customer_id                                  117329 non-null  object
#  1   customer_unique_id                           117329 non-null  object
#  2   customer_zip_code_prefix                     117329 non-null  int64
#  3   customer_city                                117329 non-null  object
#  4   customer_state                               117329 non-null  object
#  5   seller_id                                    117329 non-null  object
#  6   seller_zip_code_prefix                       117329 non-null  int64
#  7   seller_city                                  117329 non-null  object
#  8   seller_state                                 117329 non-null  object
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 46 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   customer_id                                  117329 non-null  object
#  1   customer_unique_id                           117329 non-null  object
#  2   customer_zip_code_prefix                     117329 non-null  int64
#  3   customer_city                                117329 non-null  object
#  4   customer_state                               117329 non-null  object
#  5   seller_id                                    117329 non-null  object
#  6   seller_zip_code_prefix                       117329 non-null  int64
#  7   seller_city                                  117329 non-null  object
#  8   seller_state                                 117329 non-null  object
# ...

# %%
#Drop the Time-Difference Columns with timedelta64 format
df_review_orders_payments_items_products_sellers_customers_15 = df_review_orders_payments_items_products_sellers_customers_14.drop(columns = ['Delivery-Purchase_Time_Difference', 'Estimated-Purchase_Time_Difference', 'Approval-Purchase_Time_Difference', 'Carrier_Delivered-Order_Time_Difference'])

# %%
#Drop other unnecessary columns
df_review_orders_payments_items_products_sellers_customers_16 = df_review_orders_payments_items_products_sellers_customers_15.drop(columns = ['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date'])

# %%
df_review_orders_payments_items_products_sellers_customers_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 37 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   customer_id                                  117329 non-null  object
#  1   customer_unique_id                           117329 non-null  object
#  2   customer_zip_code_prefix                     117329 non-null  int64
#  3   customer_city                                117329 non-null  object
#  4   customer_state                               117329 non-null  object
#  5   seller_id                                    117329 non-null  object
#  6   seller_zip_code_prefix                       117329 non-null  int64
#  7   seller_city                                  117329 non-null  object
#  8   seller_state                                 117329 non-null  object
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_16.corr()
# Out:
#                                              customer_zip_code_prefix  \
# customer_zip_code_prefix                                     1.000000
# seller_zip_code_prefix                                       0.076133
# product_name_lenght                                          0.016044
# product_description_lenght                                   0.025582
# product_photos_qty                                           0.020668
# product_weight_g                                             0.001731
# product_length_cm                                            0.004283
# product_height_cm                                            0.011731
# product_width_cm                                            -0.011507
# order_item_id                                               -0.003627
# price                                                        0.043273
# freight_value                                                0.225676
# ...

# %%
#Drop Unnecessary Columns
df_review_orders_payments_items_products_sellers_customers_17 = df_review_orders_payments_items_products_sellers_customers_16.drop(columns = ['product_name_lenght'])
df_review_orders_payments_items_products_sellers_customers_18 = df_review_orders_payments_items_products_sellers_customers_17.drop(columns = ['product_description_lenght'])
df_review_orders_payments_items_products_sellers_customers_19 = df_review_orders_payments_items_products_sellers_customers_18.drop(columns = ['product_photos_qty'])
df_review_orders_payments_items_products_sellers_customers_20 = df_review_orders_payments_items_products_sellers_customers_19.drop(columns = ['product_length_cm'])
df_review_orders_payments_items_products_sellers_customers_21 = df_review_orders_payments_items_products_sellers_customers_20.drop(columns = ['product_height_cm'])
df_review_orders_payments_items_products_sellers_customers_22 = df_review_orders_payments_items_products_sellers_customers_21.drop(columns = ['product_width_cm'])
df_review_orders_payments_items_products_sellers_customers_23 = df_review_orders_payments_items_products_sellers_customers_22.drop(columns = ['order_item_id'])
df_review_orders_payments_items_products_sellers_customers_24 = df_review_orders_payments_items_products_sellers_customers_23.drop(columns = ['payment_sequential'])
df_review_orders_payments_items_products_sellers_customers_25 = df_review_orders_payments_items_products_sellers_customers_24.drop(columns = ['payment_installments'])
df_review_orders_payments_items_products_sellers_customers_26 = df_review_orders_payments_items_products_sellers_customers_25.drop(columns = ['payment_value'])

# %%
df_review_orders_payments_items_products_sellers_customers_26.shape
# Out:
# (117329, 27)

# %%
df_review_orders_payments_items_products_sellers_customers_26.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 27 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   customer_id                                  117329 non-null  object
#  1   customer_unique_id                           117329 non-null  object
#  2   customer_zip_code_prefix                     117329 non-null  int64
#  3   customer_city                                117329 non-null  object
#  4   customer_state                               117329 non-null  object
#  5   seller_id                                    117329 non-null  object
#  6   seller_zip_code_prefix                       117329 non-null  int64
#  7   seller_city                                  117329 non-null  object
#  8   seller_state                                 117329 non-null  object
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_26.corr()
# Out:
#                                              customer_zip_code_prefix  \
# customer_zip_code_prefix                                     1.000000
# seller_zip_code_prefix                                       0.076133
# product_weight_g                                             0.001731
# price                                                        0.043273
# freight_value                                                0.225676
# review_score                                                -0.023349
# Delivery-Purchase_Time_Difference_Min                        0.273195
# Estimated-Purchase_Time_Difference_Min                       0.373501
# Approval-Purchase_Time_Difference_Min                        0.035774
# Carrier_Delivered-Order_Time_Difference_Min                  0.011212
#
#                                              seller_zip_code_prefix  \
# customer_zip_code_prefix                                   0.076133
# ...

# %%
plt.matshow(df_review_orders_payments_items_products_sellers_customers_26.corr())
plt.show()

# %%
#Add labels, a legend, and change the size of the heatmap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_review_orders_payments_items_products_sellers_customers_26.corr(), fignum=f.number) #type of plot
plt.xticks(range(df_review_orders_payments_items_products_sellers_customers_26.select_dtypes(['number']).shape[1]), df_review_orders_payments_items_products_sellers_customers_26.select_dtypes(['number']).columns, fontsize=11, rotation=90) #x axis labels
plt.yticks(range(df_review_orders_payments_items_products_sellers_customers_26.select_dtypes(['number']).shape[1]), df_review_orders_payments_items_products_sellers_customers_26.select_dtypes(['number']).columns, fontsize=11) #y axis labels
cb = plt.colorbar() #add color legend
cb.ax.tick_params(labelsize=8) #add font size
plt.title('Correlation Matrix', fontsize=14) #add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   zip_code_prefix    1000163 non-null  int64
#  1   geolocation_lat    1000163 non-null  float64
#  2   geolocation_lng    1000163 non-null  float64
#  3   geolocation_city   1000163 non-null  object
#  4   geolocation_state  1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
#Create geolocation subset to merge on the customer zip code
df_geolocation_cust = df_geolocation.drop_duplicates(subset = 'zip_code_prefix', keep = 'first')
df_geolocation_cust1 = df_geolocation.drop(columns = ['geolocation_city', 'geolocation_state'])

# %%
df_geolocation_cust1.shape
# Out:
# (19015, 3)

# %%
#Rename the zip_code_prefix to match the customer zip code
df_geolocation_cust1.rename(columns = {'zip_code_prefix' : 'customer_zip_code_prefix'}, inplace = True)

# %%
#Create geolocation subset to merge on the seller zip code
df_geolocation_sell = df_geolocation.drop_duplicates(subset = 'zip_code_prefix', keep = 'first')
df_geolocation_sell1 = df_geolocation.drop(columns = ['geolocation_city', 'geolocation_state'])

# %%
#Rename the zip_code_prefix to match the seller zip code
df_geolocation_sell1.rename(columns = {'zip_code_prefix' : 'seller_zip_code_prefix'}, inplace = True)

# %%
df_geolocation_sell1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19015 entries, 0 to 999846
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_zip_code_prefix  19015 non-null  int64
#  1   geolocation_lat         19015 non-null  float64
#  2   geolocation_lng         19015 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 594.2 KB

# %%
df_geolocation_sell1.shape
# Out:
# (19015, 3)

# %%
#Merge the df_geolocation_cust to the bigger dataset
df_review_orders_payments_items_products_sellers_customers_27 = df_geolocation_cust1.merge(df_review_orders_payments_items_products_sellers_customers_26, on = 'customer_zip_code_prefix')

# %%
#View the new dataset
df_review_orders_payments_items_products_sellers_customers_27.shape
# Out:
# (117013, 29)

# %%
df_review_orders_payments_items_products_sellers_customers_27.head()
# Out:
#    customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                      1037       -23.545621       -46.639292
# 1                      1037       -23.545621       -46.639292
# 2                      1037       -23.545621       -46.639292
# 3                      1037       -23.545621       -46.639292
# 4                      1046       -23.546081       -46.644820
#
#                         customer_id                customer_unique_id  \
# 0  05b005e82f3f2dcc41b5504f00484e50  3ef8c1513fc80fb905ccd8d57da5e9b8
# 1  19ee522d0dd140702062bb89e4820e19  8e7b6c489f1fe794c0ca58c80868a24b
# 2  6519f59a7687a4661f7c8a7e24f28f94  324ce23e08a1768007118a11836ea7d3
# 3  6519f59a7687a4661f7c8a7e24f28f94  324ce23e08a1768007118a11836ea7d3
# 4  9a02295e3381803554347ab4dc1ab41b  182491a144858edd68163675689069d6
#
#   customer_city customer_state                         seller_id  \
# 0     sao paulo             SP  2953ce3a88f5e3c3b696d77fc9e4c8eb
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_27.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117013 entries, 0 to 117012
# Data columns (total 29 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   customer_zip_code_prefix                     117013 non-null  int64
#  1   geolocation_lat                              117013 non-null  float64
#  2   geolocation_lng                              117013 non-null  float64
#  3   customer_id                                  117013 non-null  object
#  4   customer_unique_id                           117013 non-null  object
#  5   customer_city                                117013 non-null  object
#  6   customer_state                               117013 non-null  object
#  7   seller_id                                    117013 non-null  object
#  8   seller_zip_code_prefix                       117013 non-null  int64
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_27.head()
# Out:
#    customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                      1037       -23.545621       -46.639292
# 1                      1037       -23.545621       -46.639292
# 2                      1037       -23.545621       -46.639292
# 3                      1037       -23.545621       -46.639292
# 4                      1046       -23.546081       -46.644820
#
#                         customer_id                customer_unique_id  \
# 0  05b005e82f3f2dcc41b5504f00484e50  3ef8c1513fc80fb905ccd8d57da5e9b8
# 1  19ee522d0dd140702062bb89e4820e19  8e7b6c489f1fe794c0ca58c80868a24b
# 2  6519f59a7687a4661f7c8a7e24f28f94  324ce23e08a1768007118a11836ea7d3
# 3  6519f59a7687a4661f7c8a7e24f28f94  324ce23e08a1768007118a11836ea7d3
# 4  9a02295e3381803554347ab4dc1ab41b  182491a144858edd68163675689069d6
#
#   customer_city customer_state                         seller_id  \
# 0     sao paulo             SP  2953ce3a88f5e3c3b696d77fc9e4c8eb
# ...

# %%
#Change column types to conserve memory
df_review_orders_payments_items_products_sellers_customers_27['customer_zip_code_prefix'] = df_review_orders_payments_items_products_sellers_customers_27['customer_zip_code_prefix'].astype('int16')
df_review_orders_payments_items_products_sellers_customers_27['review_score'] = df_review_orders_payments_items_products_sellers_customers_27['review_score'].astype('int16')
df_review_orders_payments_items_products_sellers_customers_27['product_weight_g'] = df_review_orders_payments_items_products_sellers_customers_27['product_weight_g'].astype('float32')
df_review_orders_payments_items_products_sellers_customers_27['review_score'] = df_review_orders_payments_items_products_sellers_customers_27['review_score'].astype('int32')

# %%
df_review_orders_payments_items_products_sellers_customers_27.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17920949 entries, 0 to 17920948
# Data columns (total 29 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   customer_zip_code_prefix                     int16
#  1   geolocation_lat                              float64
#  2   geolocation_lng                              float64
#  3   customer_id                                  object
#  4   customer_unique_id                           object
#  5   customer_city                                object
#  6   customer_state                               object
#  7   seller_id                                    object
#  8   seller_zip_code_prefix                       int64
#  9   seller_city                                  object
#  10  seller_state                                 object
#  11  product_id                                   object
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_27.head()
# Out:
#    customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                      1037       -23.545621       -46.639292
# 1                      1037       -23.545621       -46.639292
# 2                      1037       -23.545621       -46.639292
# 3                      1037       -23.545621       -46.639292
# 4                      1046       -23.546081       -46.644820
#
#                         customer_id                customer_unique_id  \
# 0  05b005e82f3f2dcc41b5504f00484e50  3ef8c1513fc80fb905ccd8d57da5e9b8
# 1  19ee522d0dd140702062bb89e4820e19  8e7b6c489f1fe794c0ca58c80868a24b
# 2  6519f59a7687a4661f7c8a7e24f28f94  324ce23e08a1768007118a11836ea7d3
# 3  6519f59a7687a4661f7c8a7e24f28f94  324ce23e08a1768007118a11836ea7d3
# 4  9a02295e3381803554347ab4dc1ab41b  182491a144858edd68163675689069d6
#
#   customer_city customer_state                         seller_id  \
# 0     sao paulo             SP  2953ce3a88f5e3c3b696d77fc9e4c8eb
# ...

# %%
#Merge the df_geolocation_sell to the bigger dataset
df_review_orders_payments_items_products_sellers_customers_28 = df_geolocation_sell1.merge(df_review_orders_payments_items_products_sellers_customers_27, on = 'seller_zip_code_prefix')

# %%
df_review_orders_payments_items_products_sellers_customers_28.head()
# Out:
#    seller_zip_code_prefix  geolocation_lat_x  geolocation_lng_x  \
# 0                    1041         -23.544392         -46.639499
# 1                    1041         -23.544392         -46.639499
# 2                    1035         -23.541578         -46.641607
# 3                    1035         -23.541578         -46.641607
# 4                    1035         -23.541578         -46.641607
#
#    customer_zip_code_prefix  geolocation_lat_y  geolocation_lng_y  \
# 0                      7082         -23.434352         -46.542897
# 1                      4718         -15.820763         -47.901087
# 2                      1525         -23.567009         -46.637529
# 3                      1525         -23.567009         -46.637529
# 4                      1525         -23.567009         -46.637529
#
#                         customer_id                customer_unique_id  \
# 0  f3a2d5b49cc090c679649818bc3f8e8e  43926f36ab519f97f4c9ce01c6183c9c
# ...

# %%
#Rename the columns to be more logical

df_review_orders_payments_items_products_sellers_customers_28.rename(columns = {'geolocation_lat_x' : 'seller_lat'}, inplace = True)
df_review_orders_payments_items_products_sellers_customers_28.rename(columns = {'geolocation_lng_x' : 'seller_lng'}, inplace = True)
df_review_orders_payments_items_products_sellers_customers_28.rename(columns = {'geolocation_lat_y': 'customer_lat'}, inplace = True)
df_review_orders_payments_items_products_sellers_customers_28.rename(columns = {'geolocation_lng_y' : 'customer_lng'}, inplace = True)

# %%
df_review_orders_payments_items_products_sellers_customers_28.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116750 entries, 0 to 116749
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   seller_zip_code_prefix                       116750 non-null  int64
#  1   seller_lat                                   116750 non-null  float64
#  2   seller_lng                                   116750 non-null  float64
#  3   customer_zip_code_prefix                     116750 non-null  int16
#  4   customer_lat                                 116750 non-null  float64
#  5   customer_lng                                 116750 non-null  float64
#  6   customer_id                                  116750 non-null  object
#  7   customer_unique_id                           116750 non-null  object
#  8   customer_city                                116750 non-null  object
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_28.head()
# Out:
#    seller_zip_code_prefix  seller_lat  seller_lng  customer_zip_code_prefix  \
# 0                    1041  -23.544392  -46.639499                      7082
# 1                    1041  -23.544392  -46.639499                      4718
# 2                    1035  -23.541578  -46.641607                      1525
# 3                    1035  -23.541578  -46.641607                      1525
# 4                    1035  -23.541578  -46.641607                      1525
#
#    customer_lat  customer_lng                       customer_id  \
# 0    -23.434352    -46.542897  f3a2d5b49cc090c679649818bc3f8e8e
# 1    -15.820763    -47.901087  b84999d47cecf126835a23650ee4ecb8
# 2    -23.567009    -46.637529  3fc1728dbe8a2b9375d4b530b8932550
# 3    -23.567009    -46.637529  3fc1728dbe8a2b9375d4b530b8932550
# 4    -23.567009    -46.637529  3fc1728dbe8a2b9375d4b530b8932550
#
#                  customer_unique_id customer_city customer_state  ...  \
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_28.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116750 entries, 0 to 116749
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   seller_zip_code_prefix                       116750 non-null  int64
#  1   seller_lat                                   116750 non-null  float64
#  2   seller_lng                                   116750 non-null  float64
#  3   customer_zip_code_prefix                     116750 non-null  int16
#  4   customer_lat                                 116750 non-null  float64
#  5   customer_lng                                 116750 non-null  float64
#  6   customer_id                                  116750 non-null  object
#  7   customer_unique_id                           116750 non-null  object
#  8   customer_city                                116750 non-null  object
# ...

# %%
df_review_orders_payments_items_products_sellers_customers_28.corr()
# Out:
#                                              seller_zip_code_prefix  \
# seller_zip_code_prefix                                     1.000000
# seller_lat                                                -0.140512
# seller_lng                                                -0.426027
# customer_zip_code_prefix                                   0.031974
# customer_lat                                              -0.037144
# customer_lng                                              -0.038456
# product_weight_g                                           0.013879
# price                                                      0.088584
# freight_value                                              0.152446
# review_score                                               0.026146
# Delivery-Purchase_Time_Difference_Min                      0.046916
# Estimated-Purchase_Time_Difference_Min                     0.186907
# Approval-Purchase_Time_Difference_Min                      0.000084
# ...

# %%
#Export the new dataset
df_review_orders_payments_items_products_sellers_customers_28.to_csv(os.path.join(path, 'Olist-Original Data (Kaggle)','df_review_orders_payments_items_products_sellers_customers_28.csv'))

# %% [markdown]
# # Ignore the code below this row.

# %%
df_review_orders_items_payments = df_review_orders_items

# %%
df_orders_order_items_products = df_products.merge(df_orders_order_items, on = 'product_id', how ='outer')

# %%
df_orders_order_items_products_sellers = df_sellers.merge(df_orders_order_items_products, on = 'seller_id', how='outer')

# %%
df_orders_order_items_products_sellers_customers = df_customers.merge(df_orders_order_items_products_sellers, on = 'customer_id', how='outer')

# %%
df_orders_order_items_products_sellers_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                           seller_id  seller_zip_code_prefix      seller_city  \
# ...

# %%
df_orders_order_items_products_sellers_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113425 entries, 0 to 113424
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    113425 non-null  object
#  1   customer_unique_id             113425 non-null  object
#  2   customer_zip_code_prefix       113425 non-null  int64
#  3   customer_city                  113425 non-null  object
#  4   customer_state                 113425 non-null  object
#  5   seller_id                      112650 non-null  object
#  6   seller_zip_code_prefix         112650 non-null  float64
#  7   seller_city                    112650 non-null  object
#  8   seller_state                   112650 non-null  object
#  9   product_id                     112650 non-null  object
#  10  product_category_name          111047 non-null  object
#  11  product_name_lenght            111047 non-null  float64
# ...

# %%
#Convert the delivered, order purchase, order approved, estimated delivery, and order delivered to carrier dates to datetime format
df_orders_order_items_products_sellers_customers['order_purchase_timestamp'] = df_orders_order_items_products_sellers_customers['order_purchase_timestamp'].astype('datetime64[ns]')
df_orders_order_items_products_sellers_customers['order_delivered_customer_date'] = df_orders_order_items_products_sellers_customers['order_delivered_customer_date'].astype('datetime64[ns]')
df_orders_order_items_products_sellers_customers['order_estimated_delivery_date'] = df_orders_order_items_products_sellers_customers['order_estimated_delivery_date'].astype('datetime64[ns]')
df_orders_order_items_products_sellers_customers['order_delivered_carrier_date'] = df_orders_order_items_products_sellers_customers['order_delivered_carrier_date'].astype('datetime64[ns]')
df_orders_order_items_products_sellers_customers['order_approved_at'] = df_orders_order_items_products_sellers_customers['order_approved_at'].astype('datetime64[ns]')

# %%
df_orders_order_items_products_sellers_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113425 entries, 0 to 113424
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    113425 non-null  object
#  1   customer_unique_id             113425 non-null  object
#  2   customer_zip_code_prefix       113425 non-null  int64
#  3   customer_city                  113425 non-null  object
#  4   customer_state                 113425 non-null  object
#  5   seller_id                      112650 non-null  object
#  6   seller_zip_code_prefix         112650 non-null  float64
#  7   seller_city                    112650 non-null  object
#  8   seller_state                   112650 non-null  object
#  9   product_id                     112650 non-null  object
#  10  product_category_name          111047 non-null  object
#  11  product_name_lenght            111047 non-null  float64
# ...

# %%
#Calculate the time difference between actual delivery date and order purchase date
df_orders_order_items_products_sellers_customers ['Delivery-Purchase_Time_Difference'] = df_orders_order_items_products_sellers_customers['order_delivered_customer_date'] - df_orders_order_items_products_sellers_customers['order_purchase_timestamp']

#Calculate the time difference between estimated delivery date and order purchase date
df_orders_order_items_products_sellers_customers ['Estimated-Purchase_Time_Difference'] = df_orders_order_items_products_sellers_customers['order_estimated_delivery_date'] - df_orders_order_items_products_sellers_customers['order_purchase_timestamp']

#Calculate the time difference between order approval date and order purchase date
df_orders_order_items_products_sellers_customers ['Approval-Purchase_Time_Difference'] = df_orders_order_items_products_sellers_customers['order_approved_at'] - df_orders_order_items_products_sellers_customers['order_purchase_timestamp']

#Calculate the time difference between delivery to the carrier and order purchase date
df_orders_order_items_products_sellers_customers ['Carrier_Delivered-Order_Time_Difference'] = df_orders_order_items_products_sellers_customers['order_delivered_carrier_date'] - df_orders_order_items_products_sellers_customers['order_purchase_timestamp']

# %%
#Check out the new dataset with the caluclated fields
df_orders_order_items_products_sellers_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                           seller_id  seller_zip_code_prefix      seller_city  \
# ...

# %%
df_orders_order_items_products_sellers_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113425 entries, 0 to 113424
# Data columns (total 33 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   customer_id                              113425 non-null  object
#  1   customer_unique_id                       113425 non-null  object
#  2   customer_zip_code_prefix                 113425 non-null  int64
#  3   customer_city                            113425 non-null  object
#  4   customer_state                           113425 non-null  object
#  5   seller_id                                112650 non-null  object
#  6   seller_zip_code_prefix                   112650 non-null  float64
#  7   seller_city                              112650 non-null  object
#  8   seller_state                             112650 non-null  object
#  9   product_id                               112650 non-null  object
# ...

# %%
#Convert the calculated time differences into minute amounts in the integer or float format
df_geolocation_customers_sellers_items_orders_clean ['Delivery-Purchase_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Delivery-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_geolocation_customers_sellers_items_orders_clean ['Estimated-Purchase_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Estimated-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_geolocation_customers_sellers_items_orders_clean ['Approval-Purchase_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Approval-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_geolocation_customers_sellers_items_orders_clean ['Carrier_Delivered-Order_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Carrier_Delivered-Order_Time_Difference']/pd.Timedelta(minutes=1)

# %%
#Drop the Time-Difference Columns with timedelta64 format and any other unnecessary columns
df_geolocation_customers_sellers_items_orders_clean_final= df_geolocation_customers_sellers_items_orders_clean.drop(columns = ['Delivery-Order_Time_Difference', 'Delivery-Purchase_Time_Difference', 'Estimated-Purchase_Time_Difference', 'Approval-Purchase_Time_Difference', 'Carrier_Delivered-Order_Time_Difference'])

# %%
df_orders_order_items_products_sellers_customers.corr()
# Out:
#                             customer_zip_code_prefix  seller_zip_code_prefix  \
# customer_zip_code_prefix                    1.000000                0.076078
# seller_zip_code_prefix                      0.076078                1.000000
# product_name_lenght                         0.015515               -0.031412
# product_description_lenght                  0.023709                0.059581
# product_photos_qty                          0.019626               -0.045357
# product_weight_g                            0.003242                0.009709
# product_length_cm                           0.007491                0.033426
# product_height_cm                           0.011746                0.012570
# product_width_cm                           -0.008723               -0.016362
# order_item_id                              -0.000874               -0.018721
# price                                       0.042467                0.086416
# ...

# %%
print('columns:', df_orders_order_items_products_sellers_customers.columns)
print('shape:', df_orders_order_items_products_sellers_customers.shape)
# Out:
# columns: Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state', 'seller_id',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state', 'product_id',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'order_item_id', 'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')
# shape: (113425, 29)

# %%
#View the newly-merged dataset

df_orders_order_items_products_sellers_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                           seller_id  seller_zip_code_prefix      seller_city  \
# ...

# %%
#Find the null data in the dataset

type_and_missing = pd.concat([df_orders_order_items_products_sellers_customers.isnull().sum().sort_values(ascending=False),
                              ((df_orders_order_items_products_sellers_customers.isnull().sum()/df_orders_order_items_products_sellers_customers.isnull().count())*100).sort_values(ascending=False),
                              df_orders_order_items_products_sellers_customers.dtypes], axis=1, keys=['Total', 'Missing_%', 'Type'])
type_and_missing[type_and_missing['Total']>0]
# Out:
#                                Total  Missing_%     Type
# order_delivered_customer_date   3229   2.846815   object
# product_category_name           2378   2.096540   object
# product_photos_qty              2378   2.096540  float64
# product_description_lenght      2378   2.096540  float64
# product_name_lenght             2378   2.096540  float64
# order_delivered_carrier_date    1969   1.735949   object
# product_weight_g                 793   0.699140  float64
# product_height_cm                793   0.699140  float64
# product_length_cm                793   0.699140  float64
# product_width_cm                 793   0.699140  float64
# order_approved_at                790   0.696495   object
# order_id                         775   0.683271   object
# order_estimated_delivery_date    775   0.683271   object
# order_item_id                    775   0.683271  float64
# order_status                     775   0.683271   object
# ...

# %%
df_orders_order_items_products_sellers_customers.loc[df_orders_order_items_products_sellers_customers.seller_id.isnull()]['order_status'].value_counts()
# Out:
# Series([], Name: order_status, dtype: int64)

# %%
df_orders_order_items_products_sellers_customers.customer_city.nunique()
# Out:
# 4119

# %%
#Show the number of unique values for specific columns

print('Unique sellers:' , df_orders_order_items_products_sellers_customers.seller_id.nunique())
print('Unique Seller States:' , df_orders_order_items_products_sellers_customers.seller_state.nunique())
print('Unique Seller Cities:' , df_orders_order_items_products_sellers_customers.seller_city.nunique())
print('Unique Products:' , df_orders_order_items_products_sellers_customers.product_id.nunique())
print('Unique Orders:' , df_orders_order_items_products_sellers_customers.order_id.nunique())
print('Unique Product Categories:' , df_orders_order_items_products_sellers_customers.product_category_name.nunique())
print('Unique Customer Cities:' , df_orders_order_items_products_sellers_customers.customer_city.nunique())
print('Unique Customer States:' , df_orders_order_items_products_sellers_customers.customer_state.nunique())
print('Unique Customers:' , df_orders_order_items_products_sellers_customers.customer_unique_id.nunique())
# Out:
# Unique sellers: 3095
# Unique Seller States: 23
# Unique Seller Cities: 611
# Unique Products: 32951
# Unique Orders: 98666
# Unique Product Categories: 73
# Unique Customer Cities: 4119
# Unique Customer States: 27
# Unique Customers: 96096

# %%
#Look at other, valuable features of our data
total_orders = df_orders_order_items_products_sellers_customers.order_id.nunique()
total_products = df_orders_order_items_products_sellers_customers.product_id.nunique()

print('Average Price:' , df_orders_order_items_products_sellers_customers.price.sum()/total_orders)
print('Average Freight Value:' , df_orders_order_items_products_sellers_customers.freight_value.sum()/total_orders)
print('Average Product Weight:' , df_orders_order_items_products_sellers_customers.product_weight_g.sum()/total_products)
print('Total Sales:' , df_orders_order_items_products_sellers_customers.price.sum())
print('Average Number of Items per Order:' , df_orders_order_items_products_sellers_customers.order_item_id.sum()/total_orders)
# Out:
# Average Price: 137.75407637889444
# Average Freight Value: 22.823561713254826
# Average Product Weight: 7156.519377257139
# Total Sales: 13591643.7
# Average Number of Items per Order: 1.3676038351610484

# %% [markdown]
# # Statistics

# %%
#See price statstics for all orders

OrderPrices = df_orders_order_items_products_sellers_customers.groupby('order_id')['price'].sum()
OrderPrices.describe()
# Out:
# count    98666.000000
# mean       137.754076
# std        210.645145
# min          0.850000
# 25%         45.900000
# 50%         86.900000
# 75%        149.900000
# max      13440.000000
# Name: price, dtype: float64

# %%
#See price statstics for all products

ProductPrices = df_orders_order_items_products_sellers_customers.groupby('product_id')['price'].sum()
ProductPrices.describe()
# Out:
# count    32951.000000
# mean       412.480462
# std       1371.945598
# min          2.200000
# 25%         59.900000
# 50%        136.750000
# 75%        329.000000
# max      63885.000000
# Name: price, dtype: float64

# %%
#Plot Order Prices

plt.figure(figsize = (20,5))
sns.boxplot(x = OrderPrices, color = 'red')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
#Plot total Order Price (i.e. Sales) by State

pricebystate = df_orders_order_items_products_sellers_customers.groupby('customer_state')['price'].sum().sort_values(ascending=False)

plt.figure(figsize = (20, 5))
plt.title('Total Order Sales by State of the Customer')
sns.barplot(x = pricebystate.index , y= pricebystate)
# Out:
# <AxesSubplot:title={'center':'Total Order Sales by State of the Customer'}, xlabel='customer_state', ylabel='price'>

# %%
#Plot Average Order Price by State

avgpricebystate = df_orders_order_items_products_sellers_customers.groupby('customer_state')['price'].mean().sort_values(ascending=False)

plt.figure(figsize = (20, 5))
plt.title('Average Order Price by State of the Customer')
sns.barplot(x = avgpricebystate.index , y= avgpricebystate)
# Out:
# <AxesSubplot:title={'center':'Average Order Price by State of the Customer'}, xlabel='customer_state', ylabel='price'>

# %%
#Plot Total Orders by Customer's State

orderbystate = df_orders_order_items_products_sellers_customers.groupby('customer_state')['order_id'].nunique().sort_values(ascending=False)

plt.figure(figsize = (20, 5))
plt.title('Total Orders by State of the Customer')
sns.barplot(x = orderbystate.index , y = orderbystate)
# Out:
# <AxesSubplot:title={'center':'Total Orders by State of the Customer'}, xlabel='customer_state', ylabel='order_id'>

# %%
#Plot Total Orders by Seller's State

orderbysellerstate = df_orders_order_items_products_sellers_customers.groupby('seller_state')['order_id'].nunique().sort_values(ascending=False)

plt.figure(figsize = (20, 5))
plt.title('Total Orders by State of the Seller')
sns.barplot(x = orderbysellerstate.index , y = orderbysellerstate)
# Out:
# <AxesSubplot:title={'center':'Total Orders by State of the Seller'}, xlabel='seller_state', ylabel='order_id'>

# %%
#Plot Total Customers by State

customerbystate = df_orders_order_items_products_sellers_customers.groupby('customer_state')['customer_id'].nunique().sort_values(ascending=False)

plt.figure(figsize = (20, 5))
plt.title('Total Customers by State')
sns.barplot(x = customerbystate.index, y = customerbystate)
# Out:
# <AxesSubplot:title={'center':'Total Customers by State'}, xlabel='customer_state', ylabel='customer_id'>

# %%
#Plot Total Sellers by State

sellerbystate = df_orders_order_items_products_sellers_customers.groupby('seller_state')['seller_id'].nunique().sort_values(ascending=False) 

plt.figure(figsize = (20, 5))
plt.title('Total Sellers by State')
sns.barplot(x = sellerbystate.index, y = sellerbystate)
# Out:
# <AxesSubplot:title={'center':'Total Sellers by State'}, xlabel='seller_state', ylabel='seller_id'>

# %%
#Plot Average Freight Value by State

freightavgbystate = (df_orders_order_items_products_sellers_customers.groupby('customer_state')['freight_value'].sum()/df_orders_order_items_products_sellers_customers.groupby('customer_state')['order_id'].nunique()).sort_values(ascending=False)

plt.figure(figsize=(20, 5))
plt.title('Average Freight Value by State of the Customer')
sns.barplot(x = freightavgbystate.index, y = freightavgbystate)
# Out:
# <AxesSubplot:title={'center':'Average Freight Value by State of the Customer'}, xlabel='customer_state'>

# %%
df_geolocation.head()
# Out:
#    zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0             1037       -23.545621       -46.639292        sao paulo
# 1             1046       -23.546081       -46.644820        sao paulo
# 2             1046       -23.546129       -46.642951        sao paulo
# 3             1041       -23.544392       -46.639499        sao paulo
# 4             1035       -23.541578       -46.641607        sao paulo
#
#   geolocation_state
# 0                SP
# 1                SP
# 2                SP
# 3                SP
# 4                SP

# %%
#Create Subset of Customers by Geolocation Coordinates

df_geolocation = df_geolocation.drop_duplicates (subset = 'geolocation_zip_code_prefix', keep='first')

df_non_duplicates =

# %%
df_orders_order_items_products_sellers_customers.corr()
# Out:
#                             customer_zip_code_prefix  seller_zip_code_prefix  \
# customer_zip_code_prefix                    1.000000                0.076078
# seller_zip_code_prefix                      0.076078                1.000000
# product_name_lenght                         0.015515               -0.031412
# product_description_lenght                  0.023709                0.059581
# product_photos_qty                          0.019626               -0.045357
# product_weight_g                            0.003242                0.009709
# product_length_cm                           0.007491                0.033426
# product_height_cm                           0.011746                0.012570
# product_width_cm                           -0.008723               -0.016362
# order_item_id                              -0.000874               -0.018721
# price                                       0.042467                0.086416
# ...

# %%
#Export the new dataset
df_geolocation_customers_sellers_items_orders_clean_final.to_csv(os.path.join(path, 'Olist-Original Data (Kaggle)','df_geolocation_customers_sellers_items_orders_clean.csv'))

# %%
.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                           seller_id  seller_zip_code_prefix      seller_city  \
# ...

# %%
df_orders_order_items_products_sellers_customers.shape
# Out:
# (112650, 29)

# %%
#Find missing values

df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
df_geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_order_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
df_order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_order_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df_order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
df_order_reviews.tail(100)
# Out:
#                               review_id                          order_id  \
# 99124  6ec93e77f444e0b1703740a69122e35d  e1fdc6e9d1ca132377e862593a7c0bd4
# 99125  92f7668f880c5774b78a928ec7e9e5a8  666cef1ea6542e749eed5394238041a2
# 99126  f37aef9f15a081d0790c6e76ad630160  354f62589ab0a15eb57e820d6fcbe9b5
# 99127  41ab6a6885ad757f124eb3879402dae3  e5cefdab54d9844f44c6d68f3611f145
# 99128  94756df369bf6a028be944d3d05c8883  e2fbbc5e799749941a23275230ee1d8b
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_products.tail()
# Out:
#                              product_id              product_category_name  \
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
# ...

# %%
df_sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
df_product_translation.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
df_order_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df_order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_order_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
df_order_reviews['review_comment_title'].value_counts(dropna = False)
# Out:
# NaN                          87656
# Recomendo                      423
# recomendo                      345
# Bom                            293
# super recomendo                270
#                              ...
# Luminaria sobrepor led 18        1
# Não recebi.                      1
# produto com lacre violado        1
# Atraso Entrega                   1
# Foto enganosa                    1
# Name: review_comment_title, Length: 4528, dtype: int64

# %%
df_order_reviews['review_comment_message'].value_counts(dropna = False)
# Out:
# NaN                                                                                                                                                                                                    58247
# Muito bom                                                                                                                                                                                                230
# Bom                                                                                                                                                                                                      189
# muito bom                                                                                                                                                                                                122
# ...

# %%
df_orders['order_approved_at'].value_counts(dropna = False)
# Out:
# NaN                    160
# 2018-02-27 04:31:10      9
# 2018-02-06 05:31:52      7
# 2017-11-07 07:30:38      7
# 2017-12-05 10:30:42      7
#                       ...
# 2018-08-22 11:50:14      1
# 2017-09-22 11:27:36      1
# 2018-03-07 16:40:32      1
# 2017-08-08 10:50:15      1
# 2018-03-09 11:20:28      1
# Name: order_approved_at, Length: 90734, dtype: int64

# %%
df_orders['order_delivered_carrier_date'].value_counts(dropna = False)
# Out:
# NaN                    1783
# 2018-05-09 15:48:00      47
# 2018-05-10 18:29:00      32
# 2018-05-07 12:31:00      21
# 2018-07-24 16:07:00      16
#                        ...
# 2018-01-03 17:37:21       1
# 2017-10-27 20:07:58       1
# 2017-11-21 18:57:37       1
# 2018-03-21 20:03:37       1
# 2018-03-09 22:11:59       1
# Name: order_delivered_carrier_date, Length: 81019, dtype: int64

# %%
df_orders['order_delivered_customer_date'].value_counts(dropna = False)
# Out:
# NaN                    2965
# 2018-07-24 21:36:42       3
# 2018-05-08 23:38:46       3
# 2018-05-14 20:02:44       3
# 2017-12-02 00:26:45       3
#                        ...
# 2018-07-12 17:48:45       1
# 2018-05-18 18:24:36       1
# 2018-01-17 13:29:13       1
# 2018-06-29 11:21:34       1
# 2018-03-16 13:08:30       1
# Name: order_delivered_customer_date, Length: 95665, dtype: int64

# %%
df_orders.to_csv(os.path.join(path, 'Cleaned Data (Achievement 6.1)', 'df_orders_cleaned' ))

# %%
df_products['product_category_name'].value_counts(dropna = False)
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 74, dtype: int64

# %%
df_products['product_name_lenght'].value_counts(dropna = False)
# Out:
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: product_name_lenght, Length: 67, dtype: int64

# %%
df_products['product_photos_qty'].value_counts(dropna = False)
# Out:
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# NaN       610
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: product_photos_qty, dtype: int64

# %%
df_products.to_csv(os.path.join(path, 'Cleaned Data (Achievement 6.1)', 'df_products_cleaned' ))

# %%
#Time to Start Merging the Cleaned Dataframes

# %%
#Rename the geolocation_zip_code_prefix
df_geolocation.rename(columns = {'geolocation_zip_code_prefix' : 'zip_code_prefix'}, inplace = True)

# %%
#Rename the seller_zip_code_prefix
df_sellers.rename(columns = {'seller_zip_code_prefix' : 'zip_code_prefix'}, inplace = True)

# %%
#Rename the customer_zip_code_prefix
df_customers.rename(columns = {'customer_zip_code_prefix': 'zip_code_prefix'}, inplace = True)

# %%
#Merge the geolocation and sellers dataframes
df_geolocation_sellers_merged = df_geolocation.merge(df_sellers, on = 'zip_code_prefix')

# %%
df_geolocation_sellers_merged.head()
# Out:
#    zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0             1041       -23.544392       -46.639499        sao paulo
# 1             1041       -23.543539       -46.640577        sao paulo
# 2             1041       -23.543713       -46.640263        sao paulo
# 3             1041       -23.543713       -46.640263        sao paulo
# 4             1041       -23.543539       -46.640577        sao paulo
#
#   geolocation_state                         seller_id seller_city seller_state
# 0                SP  e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 1                SP  e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 2                SP  e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 3                SP  e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 4                SP  e5cbe890e679490127e9a390b46bbd20   sao paulo           SP

# %%
df_geolocation_sellers_merged
# Out:
#         zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0                  1041       -23.544392       -46.639499        sao paulo
# 1                  1041       -23.543539       -46.640577        sao paulo
# 2                  1041       -23.543713       -46.640263        sao paulo
# 3                  1041       -23.543713       -46.640263        sao paulo
# 4                  1041       -23.543539       -46.640577        sao paulo
# ...                 ...              ...              ...              ...
# 435082            99730       -27.726741       -52.538420        jacutinga
# 435083            99730       -27.729373       -52.537491        jacutinga
# 435084            99730       -27.729782       -52.533930        jacutinga
# 435085            99730       -27.727540       -52.539263        jacutinga
# 435086            99730       -27.729373       -52.537491        jacutinga
#
# ...

# %%
#Drop unecessary columns
df_geolocation_sellers_merged_clean = df_geolocation_sellers_merged.drop(columns = ['geolocation_city', 'geolocation_state'])

# %%
df_geolocation_sellers_merged_clean
# Out:
#         zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                  1041       -23.544392       -46.639499
# 1                  1041       -23.543539       -46.640577
# 2                  1041       -23.543713       -46.640263
# 3                  1041       -23.543713       -46.640263
# 4                  1041       -23.543539       -46.640577
# ...                 ...              ...              ...
# 435082            99730       -27.726741       -52.538420
# 435083            99730       -27.729373       -52.537491
# 435084            99730       -27.729782       -52.533930
# 435085            99730       -27.727540       -52.539263
# 435086            99730       -27.729373       -52.537491
#
#                                seller_id seller_city seller_state
# 0       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 1       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 2       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# ...

# %%
#Rename columns for clearer labeling
df_geolocation_sellers_merged_clean.rename(columns = {'geolocation_lat': 'seller_lat'}, inplace = True)
df_geolocation_sellers_merged_clean.rename(columns = {'geolocation_lng': 'seller_lng'}, inplace = True)

# %%
df_geolocation_sellers_merged_clean
# Out:
#         zip_code_prefix  seller_lat  seller_lng  \
# 0                  1041  -23.544392  -46.639499
# 1                  1041  -23.543539  -46.640577
# 2                  1041  -23.543713  -46.640263
# 3                  1041  -23.543713  -46.640263
# 4                  1041  -23.543539  -46.640577
# ...                 ...         ...         ...
# 435082            99730  -27.726741  -52.538420
# 435083            99730  -27.729373  -52.537491
# 435084            99730  -27.729782  -52.533930
# 435085            99730  -27.727540  -52.539263
# 435086            99730  -27.729373  -52.537491
#
#                                seller_id seller_city seller_state
# 0       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 1       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 2       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# 3       e5cbe890e679490127e9a390b46bbd20   sao paulo           SP
# ...

# %%
df_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
#Merge the geolocation-sellers and order-items dataframes
df_geolocation_sellers_items_merged_update = df_order_items.merge(df_geolocation_sellers_merged_clean, on = 'seller_id')

# %%
df_geolocation_sellers_items_merged_update.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00010242fe8c5a6d1ba2dd792cb16214              1
# 2  00010242fe8c5a6d1ba2dd792cb16214              1
# 3  00010242fe8c5a6d1ba2dd792cb16214              1
# 4  00010242fe8c5a6d1ba2dd792cb16214              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value  zip_code_prefix  seller_lat  \
# 0  2017-09-19 09:45:35   58.9          13.29            27277  -22.498183
# 1  2017-09-19 09:45:35   58.9          13.29            27277  -22.487885
# ...

# %%
df_geolocation_sellers_items_merged_update
# Out:
#                                   order_id  order_item_id  \
# 0         00010242fe8c5a6d1ba2dd792cb16214              1
# 1         00010242fe8c5a6d1ba2dd792cb16214              1
# 2         00010242fe8c5a6d1ba2dd792cb16214              1
# 3         00010242fe8c5a6d1ba2dd792cb16214              1
# 4         00010242fe8c5a6d1ba2dd792cb16214              1
# ...                                    ...            ...
# 16252414  ff701a7c869ad21de22a6994237c8a00              2
# 16252415  ff701a7c869ad21de22a6994237c8a00              2
# 16252416  ff701a7c869ad21de22a6994237c8a00              2
# 16252417  ff701a7c869ad21de22a6994237c8a00              2
# 16252418  ff701a7c869ad21de22a6994237c8a00              2
#
#                                 product_id                         seller_id  \
# 0         4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1         4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
#Drop unnecessary columns
df_geolocation_sellers_items_merged_update_clean = df_geolocation_sellers_items_merged_update.drop(columns = ['order_item_id'])

# %%
#Merge the geolocation-sellers-items and orders dataframes
df_geolocation_sellers_items_orders = df_orders.merge(df_geolocation_sellers_items_merged_update_clean, on = 'order_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1672932019.py in <module>
#       1 #Merge the geolocation-sellers-items and orders dataframes
# ----> 2 df_geolocation_sellers_items_orders = df_orders.merge(df_geolocation_sellers_items_merged_update_clean, on = 'order_id')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
# ...

# %%
df_geolocation_sellers_items_orders.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1098459132.py in <module>
# ----> 1 df_geolocation_sellers_items_orders.head()
#
# NameError: name 'df_geolocation_sellers_items_orders' is not defined

# %%
df_geolocation_sellers_items_orders
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\253426832.py in <module>
# ----> 1 df_geolocation_sellers_items_orders
#
# NameError: name 'df_geolocation_sellers_items_orders' is not defined

# %%
#Drop the unecessary columns
df_geolocation_sellers_items_orders_merged_clean = df_geolocation_sellers_items_orders.drop(columns = ['order_status', 'product_id'])

# %%
df_geolocation_sellers_items_orders_merged_clean.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1289892584.py in <module>
# ----> 1 df_geolocation_sellers_items_orders_merged_clean.head(10)
#
# NameError: name 'df_geolocation_sellers_items_orders_merged_clean' is not defined

# %%
df_geolocation_sellers_items_orders_merged_clean
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...                                    ...                               ...
# 16252414  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252415  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252416  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252417  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252418  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
#Merge the geolocation and customer dataframes
df_geolocation_customers_merged = df_customers.merge(df_geolocation, on = 'zip_code_prefix')

# %%
df_geolocation_customers_merged.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\4231197272.py in <module>
# ----> 1 df_geolocation_customers_merged.head()
#
# NameError: name 'df_geolocation_customers_merged' is not defined

# %%
#Drop the unnecessary columns prior to the merge with the geolocation_sellers_items_orders dataframe
df_geolocation_customers_clean = df_geolocation_customers_merged.drop(columns = ['customer_unique_id', 'geolocation_state', 'geolocation_city'])

# %%
df_geolocation_customers_clean
# Out:
#                                customer_id  zip_code_prefix  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7            14409
# 1         06b8999e2fba1a1fbc88172c00ba8bc7            14409
# 2         06b8999e2fba1a1fbc88172c00ba8bc7            14409
# 3         06b8999e2fba1a1fbc88172c00ba8bc7            14409
# 4         06b8999e2fba1a1fbc88172c00ba8bc7            14409
# ...                                    ...              ...
# 15083450  d9110683c7a282144e9fc97660026a28            74980
# 15083451  d9110683c7a282144e9fc97660026a28            74980
# 15083452  d9110683c7a282144e9fc97660026a28            74980
# 15083453  6fb4f2354f36e554ac80141e9128f528            99043
# 15083454  6fb4f2354f36e554ac80141e9128f528            99043
#
#                  customer_city customer_state  geolocation_lat  \
# 0                       franca             SP       -20.509897
# 1                       franca             SP       -20.497396
# ...

# %%
#Rename certain columns
df_geolocation_customers_clean.rename(columns = {'zip_code_prefix': 'customer_zip_code'}, inplace = True)
df_geolocation_customers_clean.rename(columns = {'geolocation_lat': 'customer_lat'}, inplace = True)
df_geolocation_customers_clean.rename(columns = {'geolocation_lng': 'customer_lng'}, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\3468051743.py in <module>
#       1 #Rename certain columns
# ----> 2 df_geolocation_customers_clean.rename(columns = {'zip_code_prefix': 'customer_zip_code'}, inplace = True)
#       3 df_geolocation_customers_clean.rename(columns = {'geolocation_lat': 'customer_lat'}, inplace = True)
#       4 df_geolocation_customers_clean.rename(columns = {'geolocation_lng': 'customer_lng'}, inplace = True)
#
# NameError: name 'df_geolocation_customers_clean' is not defined

# %%
df_geolocation_customers_clean
# Out:
#                                customer_id  customer_zip_code  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7              14409
# 1         06b8999e2fba1a1fbc88172c00ba8bc7              14409
# 2         06b8999e2fba1a1fbc88172c00ba8bc7              14409
# 3         06b8999e2fba1a1fbc88172c00ba8bc7              14409
# 4         06b8999e2fba1a1fbc88172c00ba8bc7              14409
# ...                                    ...                ...
# 15083450  d9110683c7a282144e9fc97660026a28              74980
# 15083451  d9110683c7a282144e9fc97660026a28              74980
# 15083452  d9110683c7a282144e9fc97660026a28              74980
# 15083453  6fb4f2354f36e554ac80141e9128f528              99043
# 15083454  6fb4f2354f36e554ac80141e9128f528              99043
#
#                  customer_city customer_state  customer_lat  customer_lng
# 0                       franca             SP    -20.509897    -47.397866
# ...

# %%
#Merge the sellers_items_orders and geolocation_customers dataframes
df_geolocation_customers_sellers_items_orders = df_geolocation.merge(df_geolocation_sellers_items_orders_merged_clean, on = 'customer_id')

# %%
df_geolocation_customers_sellers_items_orders
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\2732421087.py in <module>
# ----> 1 df_geolocation_customers_sellers_items_orders
#
# NameError: name 'df_geolocation_customers_sellers_items_orders' is not defined

# %%
#Drop unnecessary columns
df_geolocation_customers_sellers_items_orders_clean = df_geolocation_customers_sellers_items_orders.drop(columns = ['customer_unique_id', 'order_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\2690788516.py in <module>
#       1 #Drop unnecessary columns
# ----> 2 df_geolocation_customers_sellers_items_orders_clean = df_geolocation_customers_sellers_items_orders.drop(columns = ['customer_unique_id', 'order_id'])
#
# NameError: name 'df_geolocation_customers_sellers_items_orders' is not defined

# %%
#Rename certain columns
df_geolocation_customers_sellers_items_orders_clean.rename(columns = {'zip_code_prefix_x': 'customer_zip_code'}, inplace = True)
df_geolocation_customers_sellers_items_orders_clean.rename(columns = {'zip_code_prefix_y': 'seller_zip_code'}, inplace = True)
df_geolocation_customers_sellers_items_orders_clean.rename(columns = {'geolocation_lat': 'customer_lat'}, inplace = True)
df_geolocation_customers_sellers_items_orders_clean.rename(columns = {'geolocation_lng': 'customer_lng'}, inplace = True)

# %%
df_geolocation_customers_sellers_items_orders_clean
# Out:
#                                customer_id  customer_zip_code customer_city  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 1         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 2         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 3         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 4         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# ...                                    ...                ...           ...
# 16252414  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252415  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252416  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252417  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252418  274fa6071e5e17fe303b9748641082c8               6703         cotia
#
# ...

# %%
df_geolocation_customers_sellers_items_orders_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 18 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   customer_zip_code              int64
#  2   customer_city                  object
#  3   customer_state                 object
#  4   order_purchase_timestamp       object
#  5   order_approved_at              object
#  6   order_delivered_carrier_date   object
#  7   order_delivered_customer_date  object
#  8   order_estimated_delivery_date  object
#  9   seller_id                      object
#  10  shipping_limit_date            object
#  11  price                          float64
#  12  freight_value                  float64
#  13  seller_zip_code                int64
#  14  seller_lat                     float64
#  15  seller_lng                     float64
#  16  seller_city                    object
# ...

# %%
#Convert the delivered, order purchase, order approved, estimated delivery, and order delivered to carrier dates to datetime format
df_geolocation_customers_sellers_items_orders_clean['order_purchase_timestamp'] = df_geolocation_customers_sellers_items_orders_clean['order_purchase_timestamp'].astype('datetime64[ns]')
df_geolocation_customers_sellers_items_orders_clean['order_delivered_customer_date'] = df_geolocation_customers_sellers_items_orders_clean['order_delivered_customer_date'].astype('datetime64[ns]')
df_geolocation_customers_sellers_items_orders_clean['order_estimated_delivery_date'] = df_geolocation_customers_sellers_items_orders_clean['order_estimated_delivery_date'].astype('datetime64[ns]')
df_geolocation_customers_sellers_items_orders_clean['order_delivered_carrier_date'] = df_geolocation_customers_sellers_items_orders_clean['order_delivered_carrier_date'].astype('datetime64[ns]')
df_geolocation_customers_sellers_items_orders_clean['order_approved_at'] = df_geolocation_customers_sellers_items_orders_clean['order_approved_at'].astype('datetime64[ns]')

# %%
df_geolocation_customers_sellers_items_orders_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 18 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   customer_zip_code              int64
#  2   customer_city                  object
#  3   customer_state                 object
#  4   order_purchase_timestamp       datetime64[ns]
#  5   order_approved_at              datetime64[ns]
#  6   order_delivered_carrier_date   datetime64[ns]
#  7   order_delivered_customer_date  datetime64[ns]
#  8   order_estimated_delivery_date  datetime64[ns]
#  9   seller_id                      object
#  10  shipping_limit_date            object
#  11  price                          float64
#  12  freight_value                  float64
#  13  seller_zip_code                int64
#  14  seller_lat                     float64
#  15  seller_lng                     float64
# ...

# %%
df_geolocation_customers_sellers_items_orders_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\2228527702.py in <module>
# ----> 1 df_geolocation_customers_sellers_items_orders_clean
#
# NameError: name 'df_geolocation_customers_sellers_items_orders_clean' is not defined

# %%
#Calculate the time difference between actual delivery date and order purchase date
df_geolocation_customers_sellers_items_orders_clean ['Delivery-Purchase_Time_Difference'] = df_geolocation_customers_sellers_items_orders_clean['order_delivered_customer_date'] - df_geolocation_customers_sellers_items_orders_clean['order_purchase_timestamp']

#Calculate the time difference between estimated delivery date and order purchase date
df_geolocation_customers_sellers_items_orders_clean ['Estimated-Purchase_Time_Difference'] = df_geolocation_customers_sellers_items_orders_clean['order_estimated_delivery_date'] - df_geolocation_customers_sellers_items_orders_clean['order_purchase_timestamp']

#Calculate the time difference between order approval date and order purchase date
df_geolocation_customers_sellers_items_orders_clean ['Approval-Purchase_Time_Difference'] = df_geolocation_customers_sellers_items_orders_clean['order_approved_at'] - df_geolocation_customers_sellers_items_orders_clean['order_purchase_timestamp']

#Calculate the time difference between delivery to the carrier and order purchase date
df_geolocation_customers_sellers_items_orders_clean ['Carrier_Delivered-Order_Time_Difference'] = df_geolocation_customers_sellers_items_orders_clean['order_delivered_carrier_date'] - df_geolocation_customers_sellers_items_orders_clean['order_purchase_timestamp']

# %%
#Convert the calculated time differences into minute amounts in the integer or float format
df_geolocation_customers_sellers_items_orders_clean ['Delivery-Purchase_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Delivery-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_geolocation_customers_sellers_items_orders_clean ['Estimated-Purchase_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Estimated-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_geolocation_customers_sellers_items_orders_clean ['Approval-Purchase_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Approval-Purchase_Time_Difference']/pd.Timedelta(minutes=1)
df_geolocation_customers_sellers_items_orders_clean ['Carrier_Delivered-Order_Time_Difference_Min'] = df_geolocation_customers_sellers_items_orders_clean ['Carrier_Delivered-Order_Time_Difference']/pd.Timedelta(minutes=1)

# %%
df_geolocation_customers_sellers_items_orders_clean.head()
# Out:
#                         customer_id  customer_zip_code customer_city  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 1  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 2  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 3  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 4  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
#
#   customer_state order_purchase_timestamp   order_approved_at  \
# 0             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 1             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 2             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 3             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 4             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-05-23 10:47:57           2017-05-25 10:35:35
# ...

# %%
df_geolocation_customers_sellers_items_orders_clean.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\3932469142.py in <module>
# ----> 1 df_geolocation_customers_sellers_items_orders_clean.info()
#
# NameError: name 'df_geolocation_customers_sellers_items_orders_clean' is not defined

# %%
#Drop the Time-Difference Columns with timedelta64 format and any other unnecessary columns
df_geolocation_customers_sellers_items_orders_clean_final= df_geolocation_customers_sellers_items_orders_clean.drop(columns = ['Delivery-Order_Time_Difference', 'Delivery-Purchase_Time_Difference', 'Estimated-Purchase_Time_Difference', 'Approval-Purchase_Time_Difference', 'Carrier_Delivered-Order_Time_Difference'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20200\3100686669.py in <module>
#       1 #Drop the Time-Difference Columns with timedelta64 format and any other unnecessary columns
# ----> 2 df_geolocation_customers_sellers_items_orders_clean_final= df_geolocation_customers_sellers_items_orders_clean.drop(columns = ['Delivery-Order_Time_Difference', 'Delivery-Purchase_Time_Difference', 'Estimated-Purchase_Time_Difference', 'Approval-Purchase_Time_Difference', 'Carrier_Delivered-Order_Time_Difference'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_geolocation_customers_sellers_items_orders_clean_final.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1232245439.py in <module>
# ----> 1 df_geolocation_customers_sellers_items_orders_clean_final.info()
#
# NameError: name 'df_geolocation_customers_sellers_items_orders_clean_final' is not defined

# %%
df_geolocation_customers_sellers_items_orders_clean_final.head()
# Out:
#                         customer_id  customer_zip_code customer_city  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 1  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 2  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 3  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 4  06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
#
#   customer_state order_purchase_timestamp   order_approved_at  \
# 0             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 1             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 2             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 3             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
# 4             SP      2017-05-16 15:05:35 2017-05-16 15:22:12
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-05-23 10:47:57           2017-05-25 10:35:35
# ...

# %%
#Convert seller_zip_code and customer_zip_code into smaller datatypes

df_geolocation_customers_sellers_items_orders_clean_final['customer_zip_code']=df_geolocation_customers_sellers_items_orders_clean_final['customer_zip_code'].astype('int16')
df_geolocation_customers_sellers_items_orders_clean_final['seller_zip_code']=df_geolocation_customers_sellers_items_orders_clean_final['seller_zip_code'].astype('int16')

# %%
df_geolocation_customers_sellers_items_orders_clean_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 23 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   customer_id                                  object
#  1   customer_zip_code                            int16
#  2   customer_city                                object
#  3   customer_state                               object
#  4   order_purchase_timestamp                     datetime64[ns]
#  5   order_approved_at                            datetime64[ns]
#  6   order_delivered_carrier_date                 datetime64[ns]
#  7   order_delivered_customer_date                datetime64[ns]
#  8   order_estimated_delivery_date                datetime64[ns]
#  9   seller_id                                    object
#  10  shipping_limit_date                          object
#  11  price                                        float64
# ...

# %%
df_geolocation_customers_sellers_items_orders_clean_final.head()

# %% [markdown]
# # Drop rows based on missing or negative values

# %%
#Determine the number of missing values in each column
df_geolocation_customers_sellers_items_orders_clean_final.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11420\1372797044.py in <module>
#       1 #Determine the number of missing values in each column
# ----> 2 df_geolocation_customers_sellers_items_orders_clean_final.isna().sum()
#
# NameError: name 'df_geolocation_customers_sellers_items_orders_clean_final' is not defined

# %%
#Drop rows with negative values for Carrier_Delivered-Order_Time_Difference_Min

# %%
df_geolocation_customers_sellers_items_orders_clean_final
# Out:
#                                customer_id  customer_zip_code customer_city  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 1         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 2         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 3         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 4         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# ...                                    ...                ...           ...
# 16252414  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252415  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252416  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252417  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252418  274fa6071e5e17fe303b9748641082c8               6703         cotia
#
# ...

# %%
#Export the new dataset
df_geolocation_customers_sellers_items_orders_clean_final.to_csv(os.path.join(path, 'Olist-Original Data (Kaggle)','df_geolocation_customers_sellers_items_orders_clean.csv'))

# %% [markdown]
# # Disregard the Code that Follows

# %%
df_geolocation_customers_sellers_items_orders_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 18 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   zip_code_prefix                int16
#  2   customer_city                  object
#  3   customer_state                 object
#  4   order_purchase_timestamp       object
#  5   order_approved_at              object
#  6   order_delivered_carrier_date   object
#  7   order_delivered_customer_date  object
#  8   order_estimated_delivery_date  object
#  9   seller_id                      object
#  10  shipping_limit_date            object
#  11  price                          float64
#  12  freight_value                  float64
#  13  seller_zip_code                int64
#  14  seller_lat                     float64
#  15  seller_lng                     float64
#  16  seller_city                    object
# ...

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   zip_code_prefix    1000163 non-null  int64
#  1   geolocation_lat    1000163 non-null  float64
#  2   geolocation_lng    1000163 non-null  float64
#  3   geolocation_city   1000163 non-null  object
#  4   geolocation_state  1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_geolocation['zip_code_prefix']=df_geolocation['zip_code_prefix'].astype('int16')

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   zip_code_prefix    1000163 non-null  int16
#  1   geolocation_lat    1000163 non-null  float64
#  2   geolocation_lng    1000163 non-null  float64
#  3   geolocation_city   1000163 non-null  object
#  4   geolocation_state  1000163 non-null  object
# dtypes: float64(2), int16(1), object(2)
# memory usage: 32.4+ MB

# %%
df_geolocation_update = df_geolocation.drop(columns = ['geolocation_city', 'geolocation_state'])

# %%
df_geolocation_update
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng
# 0                   1037       -23.545621       -46.639292
# 1                   1046       -23.546081       -46.644820
# 2                   1046       -23.546129       -46.642951
# 3                   1041       -23.544392       -46.639499
# 4                   1035       -23.541578       -46.641607
# ...                  ...              ...              ...
# 1000158           -31122       -28.068639       -52.010705
# 1000159           -31172       -27.877125       -52.224882
# 1000160           -31122       -28.071855       -52.014716
# 1000161           -31092       -28.388932       -51.846871
# 1000162           -31122       -28.070104       -52.018658
#
# [1000163 rows x 3 columns]

# %%
df_geolocation_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 3 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   zip_code_prefix  1000163 non-null  int16
#  1   geolocation_lat  1000163 non-null  float64
#  2   geolocation_lng  1000163 non-null  float64
# dtypes: float64(2), int16(1)
# memory usage: 17.2 MB

# %%
df_geolocation_update.merge(df_geolocation_customers_sellers_items_orders_clean, on = 'zip_code_prefix')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20200\2744453027.py in <module>
# ----> 1 df_geolocation_update.merge(df_geolocation_customers_sellers_items_orders_clean, on = 'zip_code_prefix')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#     123
#     124
#
# ...

# %%
#Drop unnecessary columns
df_geolocation_customers_merged_clean = df_geolocation_customers_merged.drop(columns = ['customer_unique_id', 'geolocation_city', 'geolocation_state'])

# %%
#Change data types of conserve memory
df_geolocation_customers_merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15083455 entries, 0 to 15083454
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   zip_code_prefix  int64
#  1   geolocation_lat  float64
#  2   geolocation_lng  float64
#  3   customer_id      object
#  4   customer_city    object
#  5   customer_state   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 805.5+ MB

# %%
df_geolocation_customers_merged_clean['geolocation_lat']=df_geolocation_customers_merged_clean['geolocation_lat'].astype('float16')
df_geolocation_customers_merged_clean['geolocation_lng']=df_geolocation_customers_merged_clean['geolocation_lng'].astype('float16')
df_geolocation_customers_merged_clean['zip_code_prefix']=df_geolocation_customers_merged_clean['zip_code_prefix'].astype('int16')

# %%
df_geolocation_customers_merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15083455 entries, 0 to 15083454
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   zip_code_prefix  int16
#  1   geolocation_lat  float16
#  2   geolocation_lng  float16
#  3   customer_id      object
#  4   customer_city    object
#  5   customer_state   object
# dtypes: float16(2), int16(1), object(3)
# memory usage: 546.6+ MB

# %%
df_geolocation_customers_merged_clean
# Out:
#           zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                    1037       -23.546875         -46.6250
# 1                    1037       -23.546875         -46.6250
# 2                    1037       -23.546875         -46.6250
# 3                    1037       -23.546875         -46.6250
# 4                    1037       -23.546875         -46.6250
# ...                   ...              ...              ...
# 15083450           -31152       -27.859375         -52.3125
# 15083451           -31152       -27.859375         -52.3125
# 15083452           -31152       -27.859375         -52.3125
# 15083453           -31152       -27.859375         -52.3125
# 15083454           -31152       -27.859375         -52.3125
#
#                                customer_id customer_city customer_state
# 0         05b005e82f3f2dcc41b5504f00484e50     sao paulo             SP
# 1         19ee522d0dd140702062bb89e4820e19     sao paulo             SP
# ...

# %%
#Change the datatypes to conserve memory
df_geolocation_sellers_items_orders_merged.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 4    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Drop redundant columns

df_geolocation_sellers_items_orders_merged_clean = df_geolocation_sellers_items_orders_merged.drop(columns = ['geolocation_state', 'geolocation_city', 'order_item_id', 'order_status', 'product_id', 'seller_id'])

# %%
df_geolocation_sellers_items_orders_merged_clean.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 5  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 6  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 7  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 8  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 9  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_purchase_timestamp    order_approved_at order_delivered_carrier_date  \
# 0      2017-10-02 10:56:33  2017-10-02 11:07:15          2017-10-04 19:55:00
# ...

# %%
#Change the datatypes to conserve memory
df_geolocation_sellers_items_orders_merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 15 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       object
#  1   customer_id                    object
#  2   order_purchase_timestamp       object
#  3   order_approved_at              object
#  4   order_delivered_carrier_date   object
#  5   order_delivered_customer_date  object
#  6   order_estimated_delivery_date  object
#  7   shipping_limit_date            object
#  8   price                          float64
#  9   freight_value                  float64
#  10  zip_code_prefix                int64
#  11  geolocation_lat                float64
#  12  geolocation_lng                float64
#  13  seller_city                    object
#  14  seller_state                   object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 1.9+ GB

# %%
df_geolocation_sellers_items_orders_merged_clean['price']=df_geolocation_sellers_items_orders_merged_clean['price'].astype('float16')
df_geolocation_sellers_items_orders_merged_clean['freight_value']=df_geolocation_sellers_items_orders_merged_clean['freight_value'].astype('float16')
df_geolocation_sellers_items_orders_merged_clean['geolocation_lat']=df_geolocation_sellers_items_orders_merged_clean['geolocation_lat'].astype('float16')
df_geolocation_sellers_items_orders_merged_clean['geolocation_lng']=df_geolocation_sellers_items_orders_merged_clean['geolocation_lng'].astype('float32')
df_geolocation_sellers_items_orders_merged_clean['zip_code_prefix']=df_geolocation_sellers_items_orders_merged_clean['zip_code_prefix'].astype('int16')

# %%
df_geolocation_sellers_items_orders_merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 15 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       object
#  1   customer_id                    object
#  2   order_purchase_timestamp       object
#  3   order_approved_at              object
#  4   order_delivered_carrier_date   object
#  5   order_delivered_customer_date  object
#  6   order_estimated_delivery_date  object
#  7   shipping_limit_date            object
#  8   price                          float16
#  9   freight_value                  float16
#  10  zip_code_prefix                int16
#  11  geolocation_lat                float16
#  12  geolocation_lng                float32
#  13  seller_city                    object
#  14  seller_state                   object
# dtypes: float16(3), float32(1), int16(1), object(10)
# memory usage: 1.5+ GB

# %%
df_geolocation_sellers_items_orders_merged_clean.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 5  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 6  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 7  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 8  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 9  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
#
#   order_purchase_timestamp    order_approved_at order_delivered_carrier_date  \
# 0      2017-10-02 10:56:33  2017-10-02 11:07:15          2017-10-04 19:55:00
# ...

# %%
df_geolocation_customers_merged_clean
# Out:
#           zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                    1037       -23.546875         -46.6250
# 1                    1037       -23.546875         -46.6250
# 2                    1037       -23.546875         -46.6250
# 3                    1037       -23.546875         -46.6250
# 4                    1037       -23.546875         -46.6250
# ...                   ...              ...              ...
# 15083450           -31152       -27.859375         -52.3125
# 15083451           -31152       -27.859375         -52.3125
# 15083452           -31152       -27.859375         -52.3125
# 15083453           -31152       -27.859375         -52.3125
# 15083454           -31152       -27.859375         -52.3125
#
#                                customer_id customer_city customer_state
# 0         05b005e82f3f2dcc41b5504f00484e50     sao paulo             SP
# 1         19ee522d0dd140702062bb89e4820e19     sao paulo             SP
# ...

# %%
df_geolocation_sellers_items_orders_merged_clean
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...                                    ...                               ...
# 16252414  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252415  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252416  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252417  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252418  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
df_geolocation_sellers_items_orders_customers_merged = df_geolocation_customers_merged_clean.merge(df_geolocation_sellers_items_orders_merged_clean, on = 'customer_id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20200\2623789816.py in <module>
# ----> 1 df_geolocation_sellers_items_orders_customers_merged = df_geolocation_customers_merged_clean.merge(df_geolocation_sellers_items_orders_merged_clean, on = 'customer_id')
#
# NameError: name 'df_geolocation_customers_merged_clean' is not defined

# %%
df_geolocation_sellers_items_orders_merged_clean
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...                                    ...                               ...
# 16252414  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252415  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252416  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252417  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 16252418  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
df_geolocation_sellers_items_orders_merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16252419 entries, 0 to 16252418
# Data columns (total 15 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       object
#  1   customer_id                    object
#  2   order_purchase_timestamp       object
#  3   order_approved_at              object
#  4   order_delivered_carrier_date   object
#  5   order_delivered_customer_date  object
#  6   order_estimated_delivery_date  object
#  7   shipping_limit_date            object
#  8   price                          float16
#  9   freight_value                  float16
#  10  zip_code_prefix                int16
#  11  geolocation_lat                float16
#  12  geolocation_lng                float32
#  13  seller_city                    object
#  14  seller_state                   object
# dtypes: float16(3), float32(1), int16(1), object(10)
# memory usage: 1.5+ GB

# %%
df_geolocation
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0                   1037       -23.545621       -46.639292        sao paulo
# 1                   1046       -23.546081       -46.644820        sao paulo
# 2                   1046       -23.546129       -46.642951        sao paulo
# 3                   1041       -23.544392       -46.639499        sao paulo
# 4                   1035       -23.541578       -46.641607        sao paulo
# ...                  ...              ...              ...              ...
# 1000158            99950       -28.068639       -52.010705         tapejara
# 1000159            99900       -27.877125       -52.224882   getulio vargas
# 1000160            99950       -28.071855       -52.014716         tapejara
# 1000161            99980       -28.388932       -51.846871  david canabarro
# 1000162            99950       -28.070104       -52.018658         tapejara
#
#         geolocation_state
# 0                      SP
# ...

# %%
df_geolocation.rename(columns = {'zip_code_prefix_y' : 'zip_code_prefix'}, inplace = True)

# %%
df_geolocation
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0                   1037       -23.545621       -46.639292        sao paulo
# 1                   1046       -23.546081       -46.644820        sao paulo
# 2                   1046       -23.546129       -46.642951        sao paulo
# 3                   1041       -23.544392       -46.639499        sao paulo
# 4                   1035       -23.541578       -46.641607        sao paulo
# ...                  ...              ...              ...              ...
# 1000158            99950       -28.068639       -52.010705         tapejara
# 1000159            99900       -27.877125       -52.224882   getulio vargas
# 1000160            99950       -28.071855       -52.014716         tapejara
# 1000161            99980       -28.388932       -51.846871  david canabarro
# 1000162            99950       -28.070104       -52.018658         tapejara
#
#         geolocation_state
# 0                      SP
# ...

# %%
#Merge the geolocation data to the customers data
df_customers_geolocation = df_customers.merge(df_geolocation, on = 'zip_code_prefix')

# %%
df_customers_geolocation
# Out:
#                                customer_id                customer_unique_id  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4         06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# ...                                    ...                               ...
# 15083450  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083451  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083452  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 15083453  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
# 15083454  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
#
# ...

# %%
df_customers_geolocation_clean = df_customers_geolocation.drop(columns = ['customer_unique_id'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\2308048736.py in <module>
# ----> 1 df_customers_geolocation_clean = df_customers_geolocation.drop(columns = ['customer_unique_id'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df_customers_geolocation_clean

# %%
#Merge geolocation_sellers_items_orders with customers
df_seller_item_orders_customers = df_geolocation_sellers_items_orders_merged_clean.merge(df_customers_geolocation_clean, on = 'customer_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8468\4023129905.py in <module>
#       1 #Merge geolocation_sellers_items_orders with customers
# ----> 2 df_seller_item_orders_customers = df_geolocation_sellers_items_orders_merged_clean.merge(df_customers_geolocation_clean, on = 'customer_id')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     120         validate=validate,
# ...

# %%
df_seller_item_orders_customers

# %%
df_seller_item_orders_customers_clean = df_seller_item_orders_customers.drop(columns = ['customer_unique_id'])

# %%
#Rename columns to be more clear

df_seller_item_orders_customers_clean.rename(columns = {'zip_code_prefix_y': 'zip_code_prefix'}, inplace = True)

# %%
df_seller_item_orders_customers_clean

# %%
#Merge geolocation coordinates to the customer zip code
df_seller_item_orders_customers.merge(df_geolocation, on = 'zip_code_prefix')

# %%
df_seller_item_orders_customers_update

# %%
#Geolocation to customer zip code
df_seller_item_orders_customers_update.merge(df_geolocation  ,on = 'zip_code_prefix')

# %%
df_geolocation.drop(columns = ['geolocation_city', 'geolocation_state'])
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng
# 0                   1037       -23.545621       -46.639292
# 1                   1046       -23.546081       -46.644820
# 2                   1046       -23.546129       -46.642951
# 3                   1041       -23.544392       -46.639499
# 4                   1035       -23.541578       -46.641607
# ...                  ...              ...              ...
# 1000158            99950       -28.068639       -52.010705
# 1000159            99900       -27.877125       -52.224882
# 1000160            99950       -28.071855       -52.014716
# 1000161            99980       -28.388932       -51.846871
# 1000162            99950       -28.070104       -52.018658
#
# [1000163 rows x 3 columns]

# %%
df_geolocation
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0                   1037       -23.545621       -46.639292        sao paulo
# 1                   1046       -23.546081       -46.644820        sao paulo
# 2                   1046       -23.546129       -46.642951        sao paulo
# 3                   1041       -23.544392       -46.639499        sao paulo
# 4                   1035       -23.541578       -46.641607        sao paulo
# ...                  ...              ...              ...              ...
# 1000158            99950       -28.068639       -52.010705         tapejara
# 1000159            99900       -27.877125       -52.224882   getulio vargas
# 1000160            99950       -28.071855       -52.014716         tapejara
# 1000161            99980       -28.388932       -51.846871  david canabarro
# 1000162            99950       -28.070104       -52.018658         tapejara
#
#         geolocation_state
# 0                      SP
# ...

# %%
df_seller_item_orders_customers.merge(df_geolocation, on = 'zip_code_prefix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\590586171.py in <module>
# ----> 1 df_seller_item_orders_customers.merge(df_geolocation, on = 'zip_code_prefix')
#
# NameError: name 'df_seller_item_orders_customers' is not defined

# %%
df_seller_item_orders_customers_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\1159632483.py in <module>
# ----> 1 df_seller_item_orders_customers_clean
#
# NameError: name 'df_seller_item_orders_customers_clean' is not defined

# %%
df_geolocation
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 0                   1037       -23.545621       -46.639292        sao paulo
# 1                   1046       -23.546081       -46.644820        sao paulo
# 2                   1046       -23.546129       -46.642951        sao paulo
# 3                   1041       -23.544392       -46.639499        sao paulo
# 4                   1035       -23.541578       -46.641607        sao paulo
# ...                  ...              ...              ...              ...
# 1000158            99950       -28.068639       -52.010705         tapejara
# 1000159            99900       -27.877125       -52.224882   getulio vargas
# 1000160            99950       -28.071855       -52.014716         tapejara
# 1000161            99980       -28.388932       -51.846871  david canabarro
# 1000162            99950       -28.070104       -52.018658         tapejara
#
#         geolocation_state
# 0                      SP
# ...

# %%
df_geolocation.rename(columns = {'zip_code_prefix': ''})
# Out:
#                 geolocation_lat  geolocation_lng geolocation_city  \
# 0         1037       -23.545621       -46.639292        sao paulo
# 1         1046       -23.546081       -46.644820        sao paulo
# 2         1046       -23.546129       -46.642951        sao paulo
# 3         1041       -23.544392       -46.639499        sao paulo
# 4         1035       -23.541578       -46.641607        sao paulo
# ...        ...              ...              ...              ...
# 1000158  99950       -28.068639       -52.010705         tapejara
# 1000159  99900       -27.877125       -52.224882   getulio vargas
# 1000160  99950       -28.071855       -52.014716         tapejara
# 1000161  99980       -28.388932       -51.846871  david canabarro
# 1000162  99950       -28.070104       -52.018658         tapejara
#
#         geolocation_state
# 0                      SP
# 1                      SP
# 2                      SP
# 3                      SP
# 4                      SP
# ...

# %%
df_seller_item_orders_customers_clean.merge(df_geolocation, on = 'zip_code_prefix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\3792176287.py in <module>
# ----> 1 df_seller_item_orders_customers_clean.merge(df_geolocation, on = 'zip_code_prefix')
#
# NameError: name 'df_seller_item_orders_customers_clean' is not defined

# %%
df_geolocation_customers_merged_clean
# Out:
#           zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                    1037       -23.546875         -46.6250
# 1                    1037       -23.546875         -46.6250
# 2                    1037       -23.546875         -46.6250
# 3                    1037       -23.546875         -46.6250
# 4                    1037       -23.546875         -46.6250
# ...                   ...              ...              ...
# 15083450           -31152       -27.859375         -52.3125
# 15083451           -31152       -27.859375         -52.3125
# 15083452           -31152       -27.859375         -52.3125
# 15083453           -31152       -27.859375         -52.3125
# 15083454           -31152       -27.859375         -52.3125
#
#                                customer_id customer_city customer_state
# 0         05b005e82f3f2dcc41b5504f00484e50     sao paulo             SP
# 1         19ee522d0dd140702062bb89e4820e19     sao paulo             SP
# ...

# %%
df_geolocation_customers_merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15083455 entries, 0 to 15083454
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   zip_code_prefix  int16
#  1   geolocation_lat  float16
#  2   geolocation_lng  float16
#  3   customer_id      object
#  4   customer_city    object
#  5   customer_state   object
# dtypes: float16(2), int16(1), object(3)
# memory usage: 546.6+ MB

# %%
#Merge the customers_geolocation dataframe and the geolocation_sellers_items_orders dataframe

df_geolocation_sellers_items_orders_merged_clean.merge(df_geolocation_customers_merged_clean, on = 'customer_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\2898259893.py in <module>
#       1 #Merge the customers_geolocation dataframe and the geolocation_sellers_items_orders dataframe
#       2
# ----> 3 df_geolocation_sellers_items_orders_merged_clean.merge(df_geolocation_customers_merged_clean, on = 'customer_id')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
#Merge the geolocation_sellers_items_orders_merged and geolocation_customers_merged dataframes
df_geolocation_sellers_items_orders_customers_merged = df_geolocation_customers_merged.merge(df_geolocation_sellers_items_orders_merged, on = 'customer_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\3544721108.py in <module>
#       1 #Merge the geolocation_sellers_items_orders_merged and geolocation_customers_merged dataframes
# ----> 2 df_geolocation_sellers_items_orders_customers_merged = df_geolocation_customers_merged.merge(df_geolocation_sellers_items_orders_merged, on = 'customer_id')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9352         from pandas.core.reshape.merge import merge
#    9353
# -> 9354         return merge(
#    9355             self,
#    9356             right,
#
# ...

# %%
df_geolocation_sellers_items_orders_customers_merged.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\714282433.py in <module>
# ----> 1 df_geolocation_sellers_items_orders_customers_merged.head()
#
# NameError: name 'df_geolocation_sellers_items_orders_customers_merged' is not defined

# %%
#Drop the unnecessary columns

df_1 = df_geolocation_sellers_items_orders_customers_merged.drop(columns = ['customer_unique_id'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\1068041432.py in <module>
#       1 #Drop the unnecessary columns
#       2
# ----> 3 df_1 = df_geolocation_sellers_items_orders_customers_merged.drop(columns = ['customer_unique_id'])
#
# NameError: name 'df_geolocation_sellers_items_orders_customers_merged' is not defined

# %%
df_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\1329205716.py in <module>
# ----> 1 df_1
#
# NameError: name 'df_1' is not defined

# %%
df_2 = df_1.drop(columns = ['geolocation_state'])

# %%
df_2
# Out:
#                                customer_id  zip_code_prefix_x customer_city  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 1         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 2         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 3         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 4         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# ...                                    ...                ...           ...
# 16252414  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252415  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252416  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252417  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252418  274fa6071e5e17fe303b9748641082c8               6703         cotia
#
# ...

# %%
df_3 = df_2.drop(columns = ['geolocation_city'])

# %%
df_3
# Out:
#                                customer_id  zip_code_prefix_x customer_city  \
# 0         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 1         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 2         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 3         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# 4         06b8999e2fba1a1fbc88172c00ba8bc7              14409        franca
# ...                                    ...                ...           ...
# 16252414  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252415  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252416  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252417  274fa6071e5e17fe303b9748641082c8               6703         cotia
# 16252418  274fa6071e5e17fe303b9748641082c8               6703         cotia
#
# ...

# %%
df_4 = df_3.drop(columns = ['order_status'])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7212\3182009208.py in <module>
# ----> 1 df_4 = df_3.drop(columns = ['order_status'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df_4
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        zip_code_prefix          customer_city customer_state  \
# ...

# %%
df_5 = df_4.rename(columns = {'zip_code_prefix_x': 'customer_zip_code'}, inplace = True)

# %%
df_5

# %%
df_6 = df_5.rename(columns = {'zip_code_prefix_y': 'seller_zip_code'}, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7212\2804356006.py in <module>
# ----> 1 df_6 = df_5.rename(columns = {'zip_code_prefix_y': 'seller_zip_code'}, inplace = True)
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
df_4 = df_customers_datasets_orders_merged = df_customers.merge(df_orders, on = 'customer_id')

# %%
df_customers_datasets_orders_merged.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5920\3866278609.py in <module>
# ----> 1 df_customers_datasets_orders_merged.head()
#
# NameError: name 'df_customers_datasets_orders_merged' is not defined

# %%
df_customers_datasets_orders_order_items_merged = df_customers_datasets_orders_merged.merge(df_order_items, on = 'order_id')

# %%
df_customers_datasets_orders_order_items_merged.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
df_customers_datasets_orders_order_items_merged

# %%
#Merge the df_customers_datasets_orders_order_items_merged and 
df_customers_sellers_items_orders_order_items_merged = df_customers_datasets_orders_order_items_merged.merge(df_geolocation_sellers_items_orders_customers_merged, on = 'customer_id')

# %%
df_customers_sellers_items_orders_order_items_merged.head(10)
# Out:
#                         customer_id              customer_unique_id_x  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 5  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 6  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 7  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 8  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 9  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    zip_code_prefix customer_city_x customer_state_x  \
# 0            14409          franca               SP
# 1            14409          franca               SP
# ...

# %%
#Drop the unnecessary columns

df_customers_sellers_items_orders_order_items_merged.drop(columns = ['geolocation_state'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20200\1538870068.py in <module>
#       1 #Drop the unnecessary columns
#       2
# ----> 3 df_customers_sellers_items_orders_order_items_merged.drop(columns = ['geolocation_state'])
#
# NameError: name 'df_customers_sellers_items_orders_order_items_merged' is not defined
