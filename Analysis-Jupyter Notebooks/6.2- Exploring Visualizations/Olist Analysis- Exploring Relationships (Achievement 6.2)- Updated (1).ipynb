# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # Read the Datset Using Pandas

# %%
df = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\df_review_orders_payments_items_products_sellers_customers_28.csv', index_col = False)

# %% [markdown]
# # Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116750 entries, 0 to 116749
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Unnamed: 0                                   116750 non-null  int64
#  1   seller_zip_code_prefix                       116750 non-null  int64
#  2   seller_lat                                   116750 non-null  float64
#  3   seller_lng                                   116750 non-null  float64
#  4   customer_zip_code_prefix                     116750 non-null  int64
#  5   customer_lat                                 116750 non-null  float64
#  6   customer_lng                                 116750 non-null  float64
#  7   customer_id                                  116750 non-null  object
#  8   customer_unique_id                           116750 non-null  object
#  9   customer_city                                116750 non-null  object
#  10  customer_state                               116750 non-null  object
#  11  seller_id                                    116750 non-null  object
#  12  seller_city                                  116750 non-null  object
#  13  seller_state                                 116750 non-null  object
#  14  product_id                                   116750 non-null  object
#  15  product_category_name                        115062 non-null  object
#  16  product_weight_g                             116730 non-null  float64
#  17  order_id                                     116750 non-null  object
#  18  shipping_limit_date                          116750 non-null  object
#  19  price                                        116750 non-null  float64
#  20  freight_value                                116750 non-null  float64
#  21  payment_type                                 116750 non-null  object
#  22  review_id                                    116750 non-null  object
#  23  review_score                                 116750 non-null  int64
#  24  review_comment_title                         13826 non-null   object
#  25  review_comment_message                       49449 non-null   object
#  26  review_creation_date                         116750 non-null  object
#  27  order_status                                 116750 non-null  object
#  28  Delivery-Purchase_Time_Difference_Min        114296 non-null  float64
#  29  Estimated-Purchase_Time_Difference_Min       116750 non-null  float64
#  30  Approval-Purchase_Time_Difference_Min        116735 non-null  float64
#  31  Carrier_Delivered-Order_Time_Difference_Min  115525 non-null  float64
# dtypes: float64(11), int64(4), object(17)
# memory usage: 28.5+ MB

# %% [markdown]
# # Remove and Rename Columns

# %%
#Drop redundant columns

df_1 = df.drop(columns = ['review_comment_title'])
df_2 = df_1.drop(columns = ['shipping_limit_date'])
df_3 = df_2.drop(columns = ['review_comment_message'])
df_4 = df_3.drop(columns = ['review_creation_date'])
df_5 = df_4.drop(columns = ['Unnamed: 0'])

# %%
#Rename columns

df_5.rename(columns = {'seller_zip_code_prefix' : 'Seller_Zip'}, inplace = True)
df_5.rename(columns = {'seller_lng' : 'Seller_Long'}, inplace = True)
df_5.rename(columns = {'freight_value' : 'Freight_Value'}, inplace = True)
df_5.rename(columns = {'seller_lat' : 'Seller_Lat'}, inplace = True)
df_5.rename(columns = {'customer_lng' : 'Customer_Long'}, inplace = True)
df_5.rename(columns = {'customer_lat' : 'Customer_Lat'}, inplace = True)
df_5.rename(columns = {'customer_city' : 'Customer_City'}, inplace = True)
df_5.rename(columns = {'customer_state' : 'Customer_State'}, inplace = True)
df_5.rename(columns = {'seller_city' : 'Seller_City'}, inplace = True)
df_5.rename(columns = {'seller_state' : 'Seller_State'}, inplace = True)
df_5.rename(columns = {'product_category_name' : 'Product_Category'}, inplace = True)
df_5.rename(columns = {'product_weight_g' : 'Product_Weight(g)'}, inplace = True)
df_5.rename(columns = {'customer_zip_code_prefix' : 'Customer_Zip'}, inplace = True)
df_5.rename(columns = {'review_score' : 'Review_Score'}, inplace = True)
df_5.rename(columns = {'order_status' : 'Order_Status'}, inplace = True)
df_5.rename(columns = {'product_id' : 'Product_ID'}, inplace = True)
df_5.rename(columns = {'seller_id' : 'Seller_ID'}, inplace = True)
df_5.rename(columns = {'customer_id' : 'Customer_ID'}, inplace = True)
df_5.rename(columns = {'customer_unique_id' : 'Customer_Unique_ID'}, inplace = True)
df_5.rename(columns = {'price' : 'Price'}, inplace = True)
df_5.rename(columns = {'payment_type' : 'Payment_Type'}, inplace = True)

# %% [markdown]
# # Find Correlations between Variables

# %%
#Create a correlation matrix
df_5.corr()
# Out:
#                                              Seller_Zip  Seller_Lat  \
# Seller_Zip                                     1.000000   -0.140512
# Seller_Lat                                    -0.140512    1.000000
# Seller_Long                                   -0.426027    0.425231
# Customer_Zip                                   0.031974   -0.042737
# Customer_Lat                                  -0.037144    0.086259
# Customer_Long                                 -0.038456    0.076074
# Product_Weight(g)                              0.013879   -0.021954
# Price                                          0.088584    0.021795
# Freight_Value                                  0.152446    0.039121
# Review_Score                                   0.026146   -0.008140
# Delivery-Purchase_Time_Difference_Min          0.046916    0.050935
# Estimated-Purchase_Time_Difference_Min         0.186907    0.036731
# Approval-Purchase_Time_Difference_Min          0.000084   -0.005273
# Carrier_Delivered-Order_Time_Difference_Min    0.006083    0.000615
#
#                                              Seller_Long  Customer_Zip  \
# Seller_Zip                                     -0.426027      0.031974
# Seller_Lat                                      0.425231     -0.042737
# Seller_Long                                     1.000000     -0.050070
# Customer_Zip                                   -0.050070      1.000000
# Customer_Lat                                    0.086592     -0.422125
# Customer_Long                                   0.084336     -0.292419
# Product_Weight(g)                               0.006667      0.004967
# Price                                           0.046623     -0.014833
# Freight_Value                                  -0.006035     -0.068933
# Review_Score                                    0.010565     -0.010440
# Delivery-Purchase_Time_Difference_Min          -0.043304     -0.024438
# Estimated-Purchase_Time_Difference_Min         -0.074978     -0.041798
# Approval-Purchase_Time_Difference_Min           0.001489     -0.017164
# Carrier_Delivered-Order_Time_Difference_Min    -0.015291     -0.000023
#
#                                              Customer_Lat  Customer_Long  \
# Seller_Zip                                      -0.037144      -0.038456
# Seller_Lat                                       0.086259       0.076074
# Seller_Long                                      0.086592       0.084336
# Customer_Zip                                    -0.422125      -0.292419
# Customer_Lat                                     1.000000       0.452145
# Customer_Long                                    0.452145       1.000000
# Product_Weight(g)                                0.002013       0.000447
# Price                                            0.056942       0.016984
# Freight_Value                                    0.270747       0.090936
# Review_Score                                    -0.035630      -0.041473
# Delivery-Purchase_Time_Difference_Min            0.255956       0.108787
# Estimated-Purchase_Time_Difference_Min           0.284942       0.060522
# Approval-Purchase_Time_Difference_Min            0.019934      -0.011826
# Carrier_Delivered-Order_Time_Difference_Min      0.010530       0.009507
#
#                                              Product_Weight(g)     Price  \
# Seller_Zip                                            0.013879  0.088584
# Seller_Lat                                           -0.021954  0.021795
# Seller_Long                                           0.006667  0.046623
# Customer_Zip                                          0.004967 -0.014833
# Customer_Lat                                          0.002013  0.056942
# Customer_Long                                         0.000447  0.016984
# Product_Weight(g)                                     1.000000  0.342050
# Price                                                 0.342050  1.000000
# Freight_Value                                         0.612731  0.414241
# Review_Score                                         -0.028975 -0.004353
# Delivery-Purchase_Time_Difference_Min                 0.083899  0.061835
# Estimated-Purchase_Time_Difference_Min                0.081188  0.070544
# Approval-Purchase_Time_Difference_Min                 0.014654  0.017492
# Carrier_Delivered-Order_Time_Difference_Min           0.146448  0.063264
#
#                                              Freight_Value  Review_Score  \
# Seller_Zip                                        0.152446      0.026146
# Seller_Lat                                        0.039121     -0.008140
# Seller_Long                                      -0.006035      0.010565
# Customer_Zip                                     -0.068933     -0.010440
# Customer_Lat                                      0.270747     -0.035630
# Customer_Long                                     0.090936     -0.041473
# Product_Weight(g)                                 0.612731     -0.028975
# Price                                             0.414241     -0.004353
# Freight_Value                                     1.000000     -0.037239
# Review_Score                                     -0.037239      1.000000
# Delivery-Purchase_Time_Difference_Min             0.213512     -0.302806
# Estimated-Purchase_Time_Difference_Min            0.273374     -0.062153
# Approval-Purchase_Time_Difference_Min             0.033790     -0.024250
# Carrier_Delivered-Order_Time_Difference_Min       0.089291     -0.150539
#
#                                              Delivery-Purchase_Time_Difference_Min  \
# Seller_Zip                                                                0.046916
# Seller_Lat                                                                0.050935
# Seller_Long                                                              -0.043304
# Customer_Zip                                                             -0.024438
# Customer_Lat                                                              0.255956
# Customer_Long                                                             0.108787
# Product_Weight(g)                                                         0.083899
# Price                                                                     0.061835
# Freight_Value                                                             0.213512
# Review_Score                                                             -0.302806
# Delivery-Purchase_Time_Difference_Min                                     1.000000
# Estimated-Purchase_Time_Difference_Min                                    0.384858
# Approval-Purchase_Time_Difference_Min                                     0.085698
# Carrier_Delivered-Order_Time_Difference_Min                               0.407250
#
#                                              Estimated-Purchase_Time_Difference_Min  \
# Seller_Zip                                                                 0.186907
# Seller_Lat                                                                 0.036731
# Seller_Long                                                               -0.074978
# Customer_Zip                                                              -0.041798
# Customer_Lat                                                               0.284942
# Customer_Long                                                              0.060522
# Product_Weight(g)                                                          0.081188
# Price                                                                      0.070544
# Freight_Value                                                              0.273374
# Review_Score                                                              -0.062153
# Delivery-Purchase_Time_Difference_Min                                      0.384858
# Estimated-Purchase_Time_Difference_Min                                     1.000000
# Approval-Purchase_Time_Difference_Min                                      0.045662
# Carrier_Delivered-Order_Time_Difference_Min                                0.209701
#
#                                              Approval-Purchase_Time_Difference_Min  \
# Seller_Zip                                                                0.000084
# Seller_Lat                                                               -0.005273
# Seller_Long                                                               0.001489
# Customer_Zip                                                             -0.017164
# Customer_Lat                                                              0.019934
# Customer_Long                                                            -0.011826
# Product_Weight(g)                                                         0.014654
# Price                                                                     0.017492
# Freight_Value                                                             0.033790
# Review_Score                                                             -0.024250
# Delivery-Purchase_Time_Difference_Min                                     0.085698
# Estimated-Purchase_Time_Difference_Min                                    0.045662
# Approval-Purchase_Time_Difference_Min                                     1.000000
# Carrier_Delivered-Order_Time_Difference_Min                               0.204220
#
#                                              Carrier_Delivered-Order_Time_Difference_Min
# Seller_Zip                                                                      0.006083
# Seller_Lat                                                                      0.000615
# Seller_Long                                                                    -0.015291
# Customer_Zip                                                                   -0.000023
# Customer_Lat                                                                    0.010530
# Customer_Long                                                                   0.009507
# Product_Weight(g)                                                               0.146448
# Price                                                                           0.063264
# Freight_Value                                                                   0.089291
# Review_Score                                                                   -0.150539
# Delivery-Purchase_Time_Difference_Min                                           0.407250
# Estimated-Purchase_Time_Difference_Min                                          0.209701
# Approval-Purchase_Time_Difference_Min                                           0.204220
# Carrier_Delivered-Order_Time_Difference_Min                                     1.000000

# %%
#Create a correlation heatmap using matplotlib
plt.matshow(df_5.corr())
plt.show()

# %%
#Save figure
plt.matshow(df_5.corr())
plt.savefig("out.png")

# %%
#Current directory
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\dmlos\\Achievement VI- Olist Business Analysis'

# %%
#Add labels, a legend, and change the size of the heatmap
f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df_1.corr(), fignum=f.number) #type of plot
plt.xticks(range(df_1.select_dtypes(['number']).shape[1]), df_1.select_dtypes(['number']).columns, fontsize=11, rotation=90) #x axis labels
plt.yticks(range(df_1.select_dtypes(['number']).shape[1]), df_1.select_dtypes(['number']).columns, fontsize=11) #y axis labels
cb = plt.colorbar() #add color legend
cb.ax.tick_params(labelsize=8) #add font size
plt.title('Correlation Matrix', fontsize=14) #add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#View the columns in the dataset
df_5.columns
# Out:
# Index(['Seller_Zip', 'Seller_Lat', 'Seller_Long', 'Customer_Zip',
#        'Customer_Lat', 'Customer_Long', 'Customer_ID', 'Customer_Unique_ID',
#        'Customer_City', 'Customer_State', 'Seller_ID', 'Seller_City',
#        'Seller_State', 'Product_ID', 'Product_Category', 'Product_Weight(g)',
#        'order_id', 'Price', 'Freight_Value', 'Payment_Type', 'review_id',
#        'Review_Score', 'Order_Status', 'Delivery-Purchase_Time_Difference_Min',
#        'Estimated-Purchase_Time_Difference_Min',
#        'Approval-Purchase_Time_Difference_Min',
#        'Carrier_Delivered-Order_Time_Difference_Min'],
#       dtype='object')

# %%
#Create a subset of relevant factors that include: zip codes, time differences, freight values, and prices

sub = df_5[['Customer_Zip', 'Seller_Zip', 'Delivery-Purchase_Time_Difference_Min', 'Estimated-Purchase_Time_Difference_Min','Approval-Purchase_Time_Difference_Min', 
            'Product_Weight(g)', 'Review_Score', 'Price', 'Product_Category', 'Payment_Type','Order_Status', 'Carrier_Delivered-Order_Time_Difference_Min','Freight_Value']]

# %%
sub
# Out:
#         Customer_Zip  Seller_Zip  Delivery-Purchase_Time_Difference_Min  \
# 0               7082        1041                            2707.266667
# 1               4718        1041                           14353.433333
# 2               1525        1035                            2979.450000
# 3               1525        1035                            2979.450000
# 4               1525        1035                            2979.450000
# ...              ...         ...                                    ...
# 116745         28740       99730                           14380.666667
# 116746         30315       99730                           10503.366667
# 116747         12532       99730                           21248.666667
# 116748         17304       99730                           13127.716667
# 116749        -31572       99730                            7718.066667
#
#         Estimated-Purchase_Time_Difference_Min  \
# 0                                 33208.433333
# 1                                 23275.033333
# 2                                 20720.633333
# 3                                 20720.633333
# 4                                 20720.633333
# ...                                        ...
# 116745                            34795.916667
# 116746                            41176.750000
# 116747                            39026.666667
# 116748                            36808.866667
# 116749                            22181.400000
#
#         Approval-Purchase_Time_Difference_Min  Product_Weight(g)  \
# 0                                   27.683333              200.0
# 1                                 1128.650000              300.0
# 2                                   18.083333              230.0
# 3                                   18.083333              230.0
# 4                                   18.083333              230.0
# ...                                       ...                ...
# 116745                              19.833333             6700.0
# 116746                            7711.216667             3520.0
# 116747                              21.066667              450.0
# 116748                            4846.733333              550.0
# 116749                              11.733333             3520.0
#
#         Review_Score   Price               Product_Category Payment_Type  \
# 0                  5  329.99                   beleza_saude  credit_card
# 1                  4  579.00                   beleza_saude  credit_card
# 2                  5   17.86                     automotivo  credit_card
# 3                  5   17.86                     automotivo  credit_card
# 4                  5   17.86                     automotivo  credit_card
# ...              ...     ...                            ...          ...
# 116745             5  129.90             ferramentas_jardim  credit_card
# 116746             2   34.85  construcao_ferramentas_jardim       boleto
# 116747             5  139.00             ferramentas_jardim  credit_card
# 116748             5   65.00                   beleza_saude       boleto
# 116749             5   37.88  construcao_ferramentas_jardim  credit_card
#
#        Order_Status  Carrier_Delivered-Order_Time_Difference_Min  \
# 0         delivered                                   723.433333
# 1         delivered                                  2314.033333
# 2         delivered                                  1129.633333
# 3         delivered                                  1129.633333
# 4         delivered                                  1129.633333
# ...             ...                                          ...
# 116745    delivered                                  5158.916667
# 116746    delivered                                  6349.683333
# 116747    delivered                                  2316.666667
# 116748    delivered                                  4703.716667
# 116749    delivered                                  1594.650000
#
#         Freight_Value
# 0                9.57
# 1               19.15
# 2                7.39
# 3                7.39
# 4                7.39
# ...               ...
# 116745          51.20
# 116746          33.48
# 116747          51.47
# 116748          18.33
# 116749          19.41
#
# [116750 rows x 13 columns]

# %% [markdown]
# # Create a Correlation Heatmap

# %%
df_reviews = pd.read_csv(r'C:\Users\dmlos\Achievement VI- Olist Business Analysis\Olist-Original Data (Kaggle)\olist_order_reviews_dataset.csv')

# %%
df_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
#Create a subplot with matplotlib
f, ax = plt.subplots(figsize= (10,10))

#Create the correlation heatmap by applying a heatmap onto the correlation matrix and the subplots as defined above. Use seaborn
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) #The annot argument allows the coefficients to be placed onto the boxes in the heatmap

# %% [markdown]
# # Create Scatterplots

# %% [markdown]
# ### Relationship between Delivery Time and Estimated Delivery Time

# %%
#Create a scatterplot for the Purchase-Delivery and Estimated-Purchase Time Differences

sns.lmplot(x = 'Delivery-Purchase_Time_Difference_Min', y = 'Carrier_Delivered-Order_Time_Difference_Min', data = df_5)

# %% [markdown]
# ### Relationship Between Delivery Time and Estimated Delivery Time by Review Rating

# %%
#Create a scatterplot for the Purchase-Delivery and Estimated-Purchase Time Differences

sns.lmplot(x = 'Delivery-Purchase_Time_Difference_Min', y = 'Review_Score', data = df_5)

# %% [markdown]
# ### Relationship between Delivery Time and Estimated Delivery Time by Freight Value

# %%
#Create a scatterplot for the Purchase-Delivery and Estimated-Purchase Time Differences

sns.lmplot(x = 'Price', y = 'Freight_Value', data = df_5)

# %% [markdown]
# ### Relationship between Delivery and Estimated Delivery Times by Product Weight

# %%
#Create a scatterplot for the Purchase-Delivery and Estimated-Purchase Time Differences

sns.lmplot(x = 'Freight_Value', y = 'Product_Weight(g)', data = df_5)

# %%
#Create a scatterplot for the Carrier-Ordered Time Difference and the Delivery-Purchase Time Difference

sns.lmplot(x = 'Delivery-Purchase_Time_Difference_Min', y = 'Carrier_Delivered-Order_Time_Difference_Min', data = df_5)

# %% [markdown]
# # Create Pair Plot

# %%
#Create a subset of only the variables you want in the pair plot
sub_2 = df_5[['Customer_Zip', 'Delivery-Purchase_Time_Difference_Min', 'Product_Weight(g)', 'Review_Score', 
              'Seller_Zip','Carrier_Delivered-Order_Time_Difference_Min','Freight_Value', 'Price']]

# %%
#Create a pair plot
g = sns.pairplot(sub_2)

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ### Distribution of Delivery Times

# %%
#Create a distribution showing order fulfillment times (i.e. Delivery-Purchase Time Difference) with a kernel density function(KDE), a Gaussian Distribution,
sns.histplot(df_5['Delivery-Purchase_Time_Difference_Min'], bins = 60, kde = True)
# Out:
# <AxesSubplot:xlabel='Delivery-Purchase_Time_Difference_Min', ylabel='Count'>

# %%
df_5.loc[df_5['Delivery-Purchase_Time_Difference_Min'] < 10000 , 'Fulfillment Time'] = 'Fast'

# %%
df_5.loc[(df_5['Delivery-Purchase_Time_Difference_Min'] >= 10000) & (df_5['Delivery-Purchase_Time_Difference_Min'] < 30000) , 'Fulfillment Time'] = 'Average'

# %%
df_5.loc[df['Delivery-Purchase_Time_Difference_Min'] >= 30000 , 'Fulfillment Time'] = 'Slow'

# %%
df_5['Fulfillment Time'].value_counts(dropna = False)
# Out:
# Average    69107
# Fast       30453
# Slow       14736
# NaN         2454
# Name: Fulfillment Time, dtype: int64

# %%
df_5.columns
# Out:
# Index(['Seller_Zip', 'Seller_Lat', 'Seller_Long', 'Customer_Zip',
#        'Customer_Lat', 'Customer_Long', 'Customer_ID', 'Customer_Unique_ID',
#        'Customer_City', 'Customer_State', 'Seller_ID', 'Seller_City',
#        'Seller_State', 'Product_ID', 'Product_Category', 'Product_Weight(g)',
#        'order_id', 'Price', 'Freight_Value', 'Payment_Type', 'review_id',
#        'Review_Score', 'Order_Status', 'Delivery-Purchase_Time_Difference_Min',
#        'Estimated-Purchase_Time_Difference_Min',
#        'Approval-Purchase_Time_Difference_Min',
#        'Carrier_Delivered-Order_Time_Difference_Min', 'Fulfillment Time'],
#       dtype='object')

# %% [markdown]
# ### Fulfillment Times by Review Score

# %%
# Create a categorical plot in seaborn using the fulfillment times created above

sns.set(style="ticks")
g = sns.catplot(x='Review_Score', y='Delivery-Purchase_Time_Difference_Min', hue='Fulfillment Time', data=df_5, height=15, aspect=1.5)

# %%
#Save the categorical plot as an image

g.savefig('Fulfillment Times by Review Score.png')

# %% [markdown]
# ### Fulfillment Times by State of the Seller

# %%
# Create a categorical plot in seaborn using the fulfillment times by seller state created above

sns.set(style="ticks")
g = sns.catplot(x='Seller_State', y='Delivery-Purchase_Time_Difference_Min', hue='Fulfillment Time', data=df_5, height=15, aspect=1.5)

# %%
#Save the categorical plot as an image

g.savefig('Fulfillment Times by Seller State.png')

# %% [markdown]
# ### Fulfillment Times by State of the Customer

# %%
# Create a categorical plot in seaborn using the fulfillment times by customer state created above

sns.set(style="ticks")
g = sns.catplot(x='Customer_State', y='Delivery-Purchase_Time_Difference_Min', hue='Fulfillment Time', data=df_5, height=15, aspect=1.5)

# %%
#Save the categorical plot as an image

g.savefig('Fulfillment Times by Customer State.png')

# %% [markdown]
# ### Distribution of Approval Timelags (i.e.  Purchase - Approval Time Difference)

# %%
#Create a distribution showing approval time lags (i.e. Approval-Purchase Time Difference) with a kernel density function(KDE), a Gaussian Distribution,

sns.histplot(df_5['Approval-Purchase_Time_Difference_Min'], bins = 100, kde = True)
# Out:
# <AxesSubplot:xlabel='Approval-Purchase_Time_Difference_Min', ylabel='Count'>

# %% [markdown]
# ### Distribution of Delivery Logistics Timelags (i.e. Delivery to Carrier - Purchase Time Difference)

# %%
#Create a distribution showing delivery logistics time lags (i.e. Delivery-Purchase Time Difference) with a kernel density function(KDE), a Gaussian Distribution,
sns.histplot(df_5['Carrier_Delivered-Order_Time_Difference_Min'], bins = 100, kde = True)
# Out:
# <AxesSubplot:xlabel='Carrier_Delivered-Order_Time_Difference_Min', ylabel='Count'>

# %% [markdown]
# # Create Distribution Charts

# %%
Customer_Zip_Code = df_5['Customer_Zip'].dropna()

# %% [markdown]
# ### Distribution of Sellers by State

# %%
#Show the distribution of sellers by state
df_5['Seller_State'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Distribution of Customers by State

# %%
#Show the distribution of customers by state
df_5['Customer_State'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>
